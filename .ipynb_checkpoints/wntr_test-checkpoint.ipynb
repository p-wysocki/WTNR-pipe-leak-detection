# %%
import wntr 
import matplotlib.pyplot as plt

# %%
wn = wntr.network.WaterNetworkModel('../../Walkerton/walkerton_v1.inp')

# %%
wn.describe(level=2)
# Out:
# {'Nodes': {'Junctions': 310, 'Tanks': 2, 'Reservoirs': 3},
#  'Links': {'Pipes': 358,
#   'Pumps': {'Head': 3, 'Power': 0},
#   'Valves': {'PRV': 0, 'PSV': 0, 'PBV': 0, 'TCV': 0, 'FCV': 3, 'GPV': 0}},
#  'Patterns': 19,
#  'Curves': {'Pump': 3, 'Efficiency': 0, 'Headloss': 0, 'Volume': 0},
#  'Sources': 0,
#  'Controls': 5}

# %%
wntr.graphics.plot_network(wn, title=wn.name)
# Out:
# (<matplotlib.collections.PathCollection at 0x3b94713d0>,
#  <matplotlib.collections.LineCollection at 0x3b93aaa00>)

# %%
sim = wntr.sim.WNTRSimulator(wn)

# %%
results = sim.run_sim()
# Out:
# C:\Users\Anna\anaconda3\lib\site-packages\scipy\optimize\minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
pressure_at_5hr = results.node['pressure'].loc[5*3600, :]
wntr.graphics.plot_network(wn, node_attribute=pressure_at_5hr);

# %%
wn.junction_name_list
# Out:
# ['J1',
#  'J2',
#  'J3',
#  'J4',
#  'J5',
#  'J6',
#  'J7',
#  'J8',
#  'J9',
#  'J10',
#  'J11',
#  'J12',
#  'J13',
#  'J14',
#  'J15',
#  'J16',
#  'J17',
#  'J18',
#  'J19',
#  'J20',
#  'J21',
#  'J22',
#  'J24',
#  'J25',
#  'J26',
#  'J27',
#  'J28',
#  'J29',
#  'J30',
#  'J31',
#  'J32',
#  'J33',
#  'J34',
#  'J35',
#  'J36',
#  'J37',
#  'J38',
#  'J39',
#  'J40',
#  'J41',
#  'J42',
#  'J43',
#  'J44',
#  'J45',
#  'J46',
#  'J47',
#  'J48',
#  'J49',
#  'J50',
#  'J52',
#  'J53',
#  'J54',
#  'J56',
#  'J57',
#  'J58',
#  'J59',
#  'J60',
#  'J61',
#  'J62',
#  'J63',
#  'J64',
#  'J65',
#  'J66',
#  'J67',
#  'J68',
#  'J69',
#  'J70',
#  'J71',
#  'J72',
#  'J73',
#  'J75',
#  'J76',
#  'J77',
#  'J78',
#  'J79',
#  'J80',
#  'J81',
#  'J82',
#  'J83',
#  'J84',
#  'J85',
#  'J86',
#  'J87',
#  'J88',
#  'J89',
#  'J90',
#  'J91',
#  'J92',
#  'J93',
#  'J94',
#  'J95',
#  'J96',
#  'J97',
#  'J98',
#  'J99',
#  'J100',
#  'J102',
#  'J103',
#  'J104',
#  'J105',
#  'J106',
#  'J107',
#  'J108',
#  'J109',
#  'J110',
#  'J111',
#  'J112',
#  'J113',
#  'J114',
#  'J115',
#  'J116',
#  'J117',
#  'J118',
#  'J119',
#  'J120',
#  'J121',
#  'J122',
#  'J123',
#  'J124',
#  'J125',
#  'J126',
#  'J127',
#  'J128',
#  'J129',
#  'J130',
#  'J131',
#  'J132',
#  'J133',
#  'J134',
#  'J135',
#  'J136',
#  'J137',
#  'J138',
#  'J139',
#  'J140',
#  'J141',
#  'J142',
#  'J143',
#  'J144',
#  'J145',
#  'J146',
#  'J147',
#  'J148',
#  'J149',
#  'J150',
#  'J151',
#  'J153',
#  'J154',
#  'J155',
#  'J156',
#  'J157',
#  'J158',
#  'J159',
#  'J160',
#  'J161',
#  'J162',
#  'J163',
#  'J164',
#  'J165',
#  'J166',
#  'J167',
#  'J168',
#  'J169',
#  'J170',
#  'J171',
#  'J172',
#  'J173',
#  'J175',
#  'J176',
#  'J177',
#  'J179',
#  'J180',
#  'J181',
#  'J182',
#  'J183',
#  'J184',
#  'J185',
#  'J186',
#  'J187',
#  'J188',
#  'J189',
#  'J190',
#  'J191',
#  'J192',
#  'J193',
#  'J194',
#  'J195',
#  'J196',
#  'J197',
#  'J198',
#  'J199',
#  'J200',
#  'J202',
#  'J203',
#  'J204',
#  'J205',
#  'J206',
#  'J207',
#  'J208',
#  'J209',
#  'J210',
#  'J211',
#  'J212',
#  'J213',
#  'J214',
#  'J216',
#  'J218',
#  'J219',
#  'J220',
#  'J223',
#  'J224',
#  'J225',
#  'J226',
#  'J227',
#  'J228',
#  'J229',
#  'J230',
#  'J231',
#  'J232',
#  'J233',
#  'J235',
#  'J236',
#  'J239',
#  'J240',
#  'J241',
#  'J242',
#  'J243',
#  'J244',
#  'J245',
#  'J246',
#  'J247',
#  'J248',
#  'J249',
#  'J250',
#  'J251',
#  'J252',
#  'J253',
#  'J254',
#  'J256',
#  'J257',
#  'J258',
#  'J259',
#  'J260',
#  'J261',
#  'J262',
#  'J263',
#  'J264',
#  'J265',
#  'J267',
#  'J269',
#  'J273',
#  'J274',
#  'J275',
#  'J276',
#  'J277',
#  'J278',
#  'J279',
#  'J280',
#  'J281',
#  'J282',
#  'J283',
#  'J284',
#  'J285',
#  'J286',
#  'J287',
#  'J288',
#  'J289',
#  'J290',
#  'J291',
#  'J292',
#  'J293',
#  'J294',
#  'J295',
#  'J296',
#  'J297',
#  'J298',
#  'J299',
#  'J300',
#  'J301',
#  'J302',
#  'J303',
#  'J304',
#  'J305',
#  'J306',
#  'J307',
#  'J308',
#  'J309',
#  'J310',
#  'J311',
#  'J312',
#  'J313',
#  'J314',
#  'J315',
#  'J316',
#  'J317',
#  'J318',
#  'J319',
#  'J320',
#  'J321',
#  'J322',
#  'J323',
#  'J324',
#  'J326',
#  'J327',
#  'J539',
#  'J544',
#  'J546',
#  'JPMP51',
#  'JPMP63',
#  'JPMP72']

# %%
wn.pipe_name_list
# Out:
# ['P2',
#  'P3',
#  'P4',
#  'P5',
#  'P7',
#  'P8',
#  'P9',
#  'P10',
#  'P11',
#  'P12',
#  'P13',
#  'P14',
#  'P16',
#  'P17',
#  'P18',
#  'P19',
#  'P20',
#  'P21',
#  'P22',
#  'P23',
#  'P24',
#  'P25',
#  'P26',
#  'P27',
#  'P34',
#  'P35',
#  'P37',
#  'P38',
#  'P39',
#  'P40',
#  'P41',
#  'P42',
#  'P43',
#  'P44',
#  'P45',
#  'P46',
#  'P47',
#  'P48',
#  'P49',
#  'P50',
#  'P51',
#  'P52',
#  'P53',
#  'P54',
#  'P55',
#  'P56',
#  'P57',
#  'P59',
#  'P60',
#  'P61',
#  'P62',
#  'P63',
#  'P64',
#  'P65',
#  'P67',
#  'P68',
#  'P75',
#  'P76',
#  'P77',
#  'P78',
#  'P79',
#  'P80',
#  'P82',
#  'P83',
#  'P84',
#  'P85',
#  'P86',
#  'P87',
#  'P89',
#  'P90',
#  'P91',
#  'P92',
#  'P93',
#  'P94',
#  'P95',
#  'P96',
#  'P97',
#  'P98',
#  'P99',
#  'P100',
#  'P101',
#  'P102',
#  'P103',
#  'P104',
#  'P105',
#  'P106',
#  'P107',
#  'P108',
#  'P109',
#  'P110',
#  'P112',
#  'P113',
#  'P115',
#  'P118',
#  'P119',
#  'P120',
#  'P121',
#  'P122',
#  'P123',
#  'P124',
#  'P125',
#  'P126',
#  'P128',
#  'P129',
#  'P130',
#  'P131',
#  'P132',
#  'P133',
#  'P134',
#  'P135',
#  'P136',
#  'P138',
#  'P140',
#  'P141',
#  'P142',
#  'P143',
#  'P144',
#  'P145',
#  'P146',
#  'P147',
#  'P148',
#  'P150',
#  'P151',
#  'P153',
#  'P154',
#  'P155',
#  'P156',
#  'P157',
#  'P158',
#  'P159',
#  'P160',
#  'P161',
#  'P162',
#  'P163',
#  'P165',
#  'P166',
#  'P167',
#  'P168',
#  'P169',
#  'P170',
#  'P172',
#  'P173',
#  'P174',
#  'P177',
#  'P180',
#  'P181',
#  'P182',
#  'P183',
#  'P184',
#  'P185',
#  'P186',
#  'P187',
#  'P188',
#  'P189',
#  'P190',
#  'P191',
#  'P192',
#  'P193',
#  'P194',
#  'P195',
#  'P196',
#  'P197',
#  'P198',
#  'P199',
#  'P200',
#  'P202',
#  'P203',
#  'P204',
#  'P205',
#  'P206',
#  'P207',
#  'P208',
#  'P209',
#  'P210',
#  'P211',
#  'P212',
#  'P213',
#  'P214',
#  'P215',
#  'P216',
#  'P217',
#  'P219',
#  'P220',
#  'P221',
#  'P222',
#  'P223',
#  'P224',
#  'P226',
#  'P228',
#  'P229',
#  'P230',
#  'P231',
#  'P232',
#  'P233',
#  'P234',
#  'P235',
#  'P236',
#  'P237',
#  'P238',
#  'P239',
#  'P240',
#  'P241',
#  'P242',
#  'P243',
#  'P244',
#  'P245',
#  'P246',
#  'P249',
#  'P250',
#  'P251',
#  'P254',
#  'P255',
#  'P257',
#  'P258',
#  'P259',
#  'P261',
#  'P262',
#  'P263',
#  'P264',
#  'P266',
#  'P267',
#  'P268',
#  'P269',
#  'P270',
#  'P271',
#  'P272',
#  'P273',
#  'P274',
#  'P275',
#  'P276',
#  'P277',
#  'P278',
#  'P279',
#  'P280',
#  'P281',
#  'P283',
#  'P284',
#  'P285',
#  'P286',
#  'P287',
#  'P288',
#  'P289',
#  'P290',
#  'P291',
#  'P292',
#  'P293',
#  'P294',
#  'P295',
#  'P296',
#  'P297',
#  'P298',
#  'P299',
#  'P300',
#  'P301',
#  'P421',
#  'P422',
#  'P430',
#  'P435',
#  'P437',
#  'P438',
#  'P441',
#  'P442',
#  'P443',
#  'P444',
#  'P445',
#  'P446',
#  'P447',
#  'P448',
#  'P449',
#  'P451',
#  'P452',
#  'P453',
#  'P454',
#  'P455',
#  'P456',
#  'P457',
#  'P458',
#  'P459',
#  'P460',
#  'P461',
#  'P462',
#  'P463',
#  'P464',
#  'P465',
#  'P466',
#  'P467',
#  'P468',
#  'P469',
#  'P471',
#  'P472',
#  'P473',
#  'P474',
#  'P475',
#  'P476',
#  'P477',
#  'P478',
#  'P479',
#  'P480',
#  'P481',
#  'P482',
#  'P483',
#  'P484',
#  'P485',
#  'P486',
#  'P488',
#  'P489',
#  'P490',
#  'P491',
#  'P492',
#  'P493',
#  'P494',
#  'P495',
#  'P496',
#  'P497',
#  'P498',
#  'P499',
#  'P500',
#  'P501',
#  'P502',
#  'P503',
#  'P504',
#  'P505',
#  'P506',
#  'P507',
#  'P508',
#  'P509',
#  'P510',
#  'P511',
#  'P512',
#  'P513',
#  'P514',
#  'P516',
#  'P517',
#  'P518',
#  'P520',
#  'P521',
#  'P523',
#  'P524',
#  'P525',
#  'P526',
#  'P527',
#  'P528',
#  'P529',
#  'P530',
#  'P531',
#  'P532',
#  'P533',
#  'P534',
#  'P535',
#  'P536',
#  'P538',
#  'P539',
#  'P544',
#  'P546',
#  'P548',
#  'P549',
#  'P551',
#  'P553']

# %%
pipe = wn.get_link('P2')

# %%
pipe.todict()
# Out:
# {'bulk_coeff': None,
#  'cv': False,
#  'diameter': 0.25,
#  'end_node': <Junction 'J3', elevation=283.81, demand_timeseries_list=<Demands: [<TimeSeries: base=0.0, pattern='R', category='None'>]>>,
#  'end_node_name': 'J3',
#  'flow': None,
#  'initial_setting': None,
#  'initial_status': <LinkStatus.Open: 1>,
#  'length': 120.0,
#  'link_type': 'Pipe',
#  'minor_loss': 0.0,
#  'name': 'P2',
#  'roughness': 70.0,
#  'setting': None,
#  'start_node': <Junction 'J2', elevation=283.69, demand_timeseries_list=<Demands: [<TimeSeries: base=7.833333333333333e-06, pattern='R', category='None'>]>>,
#  'start_node_name': 'J2',
#  'status': <LinkStatus.Open: 1>,
#  'tag': None,
#  'vertices': [],
#  'wall_coeff': None}

# %% [markdown]
# ### Symulacja wycieku

# %%
wn = wntr.network.WaterNetworkModel('../../Walkerton/walkerton_v1.inp')
sim = wntr.sim.WNTRSimulator(wn)

# %%
results.node['pressure']
# Out:
#                 J1         J2         J3         J4         J5         J6  \
# 0        36.011416  30.044852  29.924852  31.958688  32.148688  45.531102
# 3600     36.643471  30.803467  30.683467  32.673468  32.863468  45.903506
# 7200     36.438482  30.598478  30.478478  32.468479  32.658479  45.698517
# 10800    36.233493  30.393490  30.273490  32.263490  32.453490  45.493529
# 14400    36.028505  30.188501  30.068501  32.058502  32.248502  45.288540
# ...            ...        ...        ...        ...        ...        ...
# 2404800  35.267376  29.429974  29.309974  31.299060  31.489060  44.523803
# 2408400  35.057688  29.223811  29.103811  31.091668  31.281668  44.307221
# 2412000  34.753059  28.920811  28.800811  30.788101  30.978101  44.000106
# 2415600  34.448517  28.605918  28.485918  30.476808  30.666808  43.714192
# 2419200  34.592416  28.759904  28.639904  30.627286  30.817286  43.837808
#
#                 J7         J8         J9        J10  ...       J544  \
# 0        31.841401  28.841400  33.861399  43.310270  ...  81.794900
# 3600     32.473456  29.473455  34.493454  43.604068  ...  24.449732
# 7200     32.268468  29.268467  34.288465  43.399079  ...  24.244744
# 10800    32.063479  29.063478  34.083477  43.194090  ...  24.039755
# 14400    31.858490  28.858489  33.878488  42.989102  ...  23.834766
# ...            ...        ...        ...        ...  ...        ...
# 2404800  31.097051  28.097016  33.117008  42.223809  ...  23.074537
# 2408400  30.887505  27.887470  32.907492  42.006080  ...  22.829099
# 2412000  30.582762  27.582696  32.602749  41.698390  ...  22.514364
# 2415600  30.278503  27.278502  32.298500  41.417253  ...  22.304663
# 2419200  30.422401  27.422400  32.442399  41.534464  ...  22.338103
#
#               J546     JPMP51  JPMP63      JPMP72         T1         T2   R5  \
# 0        77.808845  51.588782   96.37   89.980504  26.000000  20.000000  0.0
# 3600     21.179732  72.180000   96.37  118.600000  26.220289  20.074567  0.0
# 7200     20.974744  72.180000   96.37  118.600000  26.220289  19.869578  0.0
# 10800    20.769755  72.180000   96.37  118.600000  26.220289  19.664589  0.0
# 14400    20.564766  72.180000   96.37  118.600000  26.220289  19.459601  0.0
# ...            ...        ...     ...         ...        ...        ...  ...
# 2404800  19.804537  72.180000   96.37  118.600000  25.635489  19.150765  0.0
# 2408400  19.559099  72.180000   96.37  118.600000  25.436400  18.757924  0.0
# 2412000  19.244364  72.180000   96.37  118.600000  25.136646  18.412340  0.0
# 2415600  19.034663  72.180000   96.37  118.600000  24.801075  18.077454  0.0
# 2419200  19.068103  72.180000   96.37  118.600000  24.974814  17.806084  0.0
#
#           R6   R7
# 0        0.0  0.0
# 3600     0.0  0.0
# 7200     0.0  0.0
# 10800    0.0  0.0
# 14400    0.0  0.0
# ...      ...  ...
# 2404800  0.0  0.0
# 2408400  0.0  0.0
# 2412000  0.0  0.0
# 2415600  0.0  0.0
# 2419200  0.0  0.0
#
# [673 rows x 315 columns]

# %%
results = sim.run_sim()
res1_demand = results.node['demand'].loc[:, 'J123']
res1_pressure123 = results.node['pressure'].loc[:, 'J123']
res1_pressure125 = results.node['pressure'].loc[:, 'J125']
res1_pressure63 = results.node['pressure'].loc[:, 'J63']
res1_pressure45 = results.node['pressure'].loc[:, 'J45']
res1_pressure244 = results.node['pressure'].loc[:, 'J244']
# Out:
# C:\Users\Anna\anaconda3\lib\site-packages\scipy\optimize\minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
node = wn.get_node('J123')
node.add_leak(wn, area=0.005, start_time=2*3600, end_time=12*3600)

# %%
wn.reset_initial_values()
results2 = sim.run_sim()
res2_demand = results2.node['demand'].loc[:, 'J123']
res2_pressure123 = results2.node['pressure'].loc[:, 'J123']
res2_pressure125 = results2.node['pressure'].loc[:, 'J125']
res2_pressure63 = results2.node['pressure'].loc[:, 'J63']
res2_pressure45 = results2.node['pressure'].loc[:, 'J45']
res2_pressure244 = results2.node['pressure'].loc[:, 'J244']

# %%
plt.figure(figsize=(18,6))
plt.plot(res1_demand)
plt.plot(res2_demand)

# %%
plt.figure(figsize=(18,6))
plt.plot(res1_pressure123)
plt.plot(res2_pressure123)

# %%
plt.figure(figsize=(18,6))
plt.plot(res1
# 2415600  312.717454  284.26  280.0  286.66
# 2419200  312.446084  284.26  280.0  286.66
#
# [673 rows x 315 columns]

# %%
results.node.keys()
# Out:
# odict_keys(['head', 'demand', 'pressure', 'leak_demand'])

# %%
results.link.keys()
# Out:
# odict_keys(['flowrate', 'velocity', 'status'])

# %%
wn.options.hydraulic.demand_model
# Out:
# 'DDA'

# %%
wn.reservoir_name_list
# Out:
# ['R5', 'R6', 'R7']

# %%
wn.pump_name_list
# Out:
# ['PMP51', 'PMP63', 'PMP72']

# %%
p = wn.get_pattern('R')

# %%
len(p.multipliers)
# Out:
# 336

# %%
plt.plot(p.multipliers)

# %%
plt.figure(figsize=(18,6))
plt.plot(results.node['demand'].loc[:, 'J1'])

# %%
plt.figure(figsize=(18,6))
plt.plot(results.node['pressure'].loc[:, 'J1'])

# %%
diameter = wn.query_link_attribute('diameter')
wG = wn.get_graph(wn, link_weight=diameter)

# %%
pump = wn.get_link('PMP51')
ax = wntr.graphics.plot_pump_curve(pump)

# %%
G = wn.get_graph()

# %%
wG.get_edge_data('J1', 'J6')
# Out:
# {'P4': {'type': 'Pipe', 'weight': 0.25}}

# %%
G.nodes
# Out:
# NodeView(('J1', 'J2', 'J3', 'J4', 'J5', 'J6', 'J7', 'J8', 'J9', 'J10', 'J11', 'J12', 'J13', 'J14', 'J15', 'J16', 'J17', 'J18', 'J19', 'J20', 'J21', 'J22', 'J24', 'J25', 'J26', 'J27', 'J28', 'J29', 'J30', 'J31', 'J32', 'J33', 'J34', 'J35', 'J36', 'J37', 'J38', 'J39', 'J40', 'J41', 'J42', 'J43', 'J44', 'J45', 'J46', 'J47', 'J48', 'J49', 'J50', 'J52', 'J53', 'J54', 'J56', 'J57', 'J58', 'J59', 'J60', 'J61', 'J62', 'J63', 'J64', 'J65', 'J66', 'J67', 'J68', 'J69', 'J70', 'J71', 'J72', 'J73', 'J75', 'J76', 'J77', 'J78', 'J79', 'J80', 'J81', 'J82', 'J83', 'J84', 'J85', 'J86', 'J87', 'J88', 'J89', 'J90', 'J91', 'J92', 'J93', 'J94', 'J95', 'J96', 'J97', 'J98', 'J99', 'J100', 'J102', 'J103', 'J104', 'J105', 'J106', 'J107', 'J108', 'J109', 'J110', 'J111', 'J112', 'J113', 'J114', 'J115', 'J116', 'J117', 'J118', 'J119', 'J120', 'J121', 'J122', 'J123', 'J124', 'J125', 'J126', 'J127', 'J128', 'J129', 'J130', 'J131', 'J132', 'J133', 'J134', 'J135', 'J136', 'J137', 'J138', 'J139', 'J140', 'J141', 'J142', 'J143', 'J144', 'J145', 'J146', 'J147', 'J148', 'J149', 'J150', 'J151', 'J153', 'J154', 'J155', 'J156', 'J157', 'J158', 'J159', 'J160', 'J161', 'J162', 'J163', 'J164', 'J165', 'J166', 'J167', 'J168', 'J169', 'J170', 'J171', 'J172', 'J173', 'J175', 'J176', 'J177', 'J179', 'J180', 'J181', 'J182', 'J183', 'J184', 'J185', 'J186', 'J187', 'J188', 'J189', 'J190', 'J191', 'J192', 'J193', 'J194', 'J195', 'J196', 'J197', 'J198', 'J199', 'J200', 'J202', 'J203', 'J204', 
164', 'P284'), ('J105', 'J106', 'P102'), ('J105', 'J48', 'P103'), ('J106', 'J107', 'P172'), ('J107', 'J172', 'P173'), ('J108', 'J109', 'P105'), ('J108', 'J169', 'P169'), ('J108', 'J67', 'P269'), ('J109', 'J110', 'P106'), ('J109', 'J148', 'P144'), ('J110', 'J111', 'P107'), ('J110', 'J194', 'P285'), ('J111', 'J112', 'P ...

# %%
import networkx as nx

# %%
sG = nx.Graph(G) # directed simple graph

# %%
wn.options
# Out:
# Options(time=TimeOptions(duration=2419200.0, hydraulic_timestep=3600.0, quality_timestep=3600.0, rule_timestep=360.0, pattern_timestep=1800.0, pattern_start=0.0, report_timestep=3600, report_start=0.0, start_clocktime=0.0, statistic='NONE'), hydraulic=HydraulicOptions(headloss='H-W', hydraulics=None, hydraulics_filename=None, viscosity=1.0, specific_gravity=1.0, pattern='F', demand_multiplier=1.0, demand_model='DDA', minimum_pressure=0.0, required_pressure=0.07, pressure_exponent=0.5, emitter_exponent=0.5, trials=40, accuracy=0.001, unbalanced='CONTINUE', unbalanced_value=10, checkfreq=2, maxcheck=10, damplimit=0.0, headerror=0.0, flowchange=0.0, inpfile_units='LPM', diffusivity=1.0), report=ReportOptions(pagesize=0, report_filename=None, status='NO', summary='NO', energy='NO', nodes=False, links=False, report_params={'elevation': False, 'demand': True, 'head': True, 'pressure': True, 'quality': True, 'length': False, 'diameter': False, 'flow': True, 'velocity': True, 'headloss': True, 'position': False, 'setting': False, 'reaction': False, 'f-factor': False}, param_opts={'elevation': {}, 'demand': {}, 'head': {}, 'pressure': {}, 'quality': {}, 'length': {}, 'diameter': {}, 'flow': {}, 'velocity': {}, 'headloss': {}, 'position': {}, 'setting': {}, 'reaction': {}, 'f-factor': {}}), quality=QualityOptions(parameter='CHEMICAL', trace_node=None, chemical_name='EColi', diffusivity=1.0, tolerance=0.01, inpfile_units='mg/L'), reaction=ReactionOptions(bulk_order=1.0, wall_order=1.0, tank_order=1.0, bulk_coeff=0.0, wall_coeff=0.0, limiting_potential=0.0, roughness_correl=0.0), energy=EnergyOptions(global_price=0.0, global_pattern=None, global_efficiency=75.0, demand_charge=0.0), graphics=GraphicsOptions(dimensions=['483482.37', '4884198.45', '489212.08', '4887545.13'], units='NONE', offset=['0.00', '0.00'], image_filename=None, map_filename=None), user=UserOptions())

# %%
2419200.0/3600/24
# Out:
# 28.0

# %%
for pipe_name, pipe in wn.pipes():
    print(pipe_name, " ", pipe.diameter)
# Out:
# P2   0.25
# P3   0.25
# P4   0.25
# P5   0.25
# P7   0.25
# P8   0.25
# P9   0.25
# P10   0.25
# P11   0.25
# P12   0.25
# P13   0.25
# P14   0.25
# P16   0.25
# P17   0.25
# P18   0.25
# P19   0.25
# P20   0.25
# P21   0.25
# P22   0.25
# P23   0.25
# P24   0.25
# P25   0.25
# P26   0.25
# P27   0.25
# P34   0.3
# P35   0.3
# P37   0.3
# P38   0.3
# P39   0.3
# P40   0.3
# P41   0.3
# P42   0.15
# P43   0.3
# P44   0.25
# P45   0.3
# P46   0.3
# P47   0.3
# P48   0.3
# P49   0.3
# P50   0.3
# P51   0.3
# P52   0.3
# P53   0.3
# P54   0.2
# P55   0.2
# P56   0.2
# P57   0.2
# P59   0.15
# P60   0.15
# P61   0.15
# P62   0.15
# P63   0.15
# P64   0.15
# P65   0.15
# P67   0.15
# P68   0.15
# P75   0.15
# P76   0.15
# P77   0.15
# P78   0.15
# P79   0.15
# P80   0.15
# P82   0.15
# P83   0.15
# P84   0.15
# P85   0.15
# P86   0.15
# P87   0.15
# P89   0.15
# P90   0.15
# P91   0.15
# P92   0.15
# P93   0.15
# P94   0.15
# P95   0.15
# P96   0.15
# P97   0.15
# P98   0.15
# P99   0.15
# P100   0.15
# P101   0.15
# P102   0.15
# P103   0.15
# P104   0.15
# P105   0.15
# P106   0.15
# P107   0.15
# P108   0.15
# P109   0.15
# P110   0.15
# P112   0.15
# P113   0.15
# P115   0.15
# P118   0.15
# P119   0.15
# P120   0.15
# P121   0.15
# P122   0.15
# P123   0.15
# P124   0.15
# P125   0.15
# P126   0.15
# P128   0.15
# P129   0.15
# P130   0.15
# P131   0.15
# P132   0.15
# P133   0.15
# P134   0.15
# P135   0.15
# P136   0.15
# P138   0.15
# P140   0.15
# P141   0.15
# P142   0.15
# P143   0.15
# P144   0.15
# P145   0.15
# P146   0.1
# P147   0.1
# P148   0.1
# P150   0.1
# P151   0.1
# P153   0.1
# P154   0.1
# P155   0.1
# P156   0.1
# P157   0.1
# P158   0.1
# P159   0.1
# P160   0.1
# P161   0.25
# P162   0.1
# P163   0.1
# P165   0.15
# P166   0.15
# P167   0.15
# P168   0.1
# P169   0.1
# P170   0.1
# P172   0.15
# P173   0.15
# P174   0.15
# P177   0.15
# P180   0.02
# P181   0.02
# P182   0.02
# P183   0.032
# P184   0.15
# P185   0.02
# P186   0.02
# P187   0.02
# P188   0.02
# P189   0.1
# P190   0.02
# P191   0.025
# P192   0.02
# P193   0.025
# P194   0.02
# P195   0.02
# P196   0.02
# P197   0.02
# P198   0.02
# P199   0.05
# P200   0.05
# P202   0.05
# P203   0.05
# P204   0.1
# P205   0.1
# P206   0.1
# P207   0.05
# P208   0.05
# P209   0.05
# P210   0.05
# P211   0.025
# P212   0.025
# P213   0.025
# P214   0.025
# P215   0.025
# P216   0.025
# P217   0.025
# P219   0.025
# P220   0.025
# P221   0.02
# P222   0.025
# P223   0.025
# P224   0.025
# P226   0.15
# P228   0.019
# P229   0.019
# P230   0.019
# P231   0.019
# P232   0.025
# P233   0.019
# P234   0.032
# P235   0.012
# P236   0.012
# P237   0.3
# P238   0.3
# P239   0.05
# P240   0.15
# P241   0.2
# P242   0.019
# P243   0.019
# P244   0.15
# P245   0.15
# P246   0.15
# P249   0.2
# P250   0.15
# P251   0.15
# P254   0.1
# P255   0.1
# P257   0.02
# P258   0.15
# P259   0.05
# P261   0.15
# P262   0.15
# P263   0.05
# P264   0.1
# P266   0.25
# P267   0.15
# P268   0.05
# P269   0.15
# P270   0.1
# P271   0.15
# P272   0.15
# P273   0.15
# P274   0.02
# P275   0.15
# P276   0.15
# P277   0.15
# P278   0.15
# P279   0.1
# P280   0.1
# P281   0.1
# P283   0.15
# P284   0.1
# P285   0.02
# P286   0.1
# P287   0.15
# P288   0.15
# P289   0.15
# P290   0.032
# P291   0.2
# P292   0.15
# P293   0.032
# P294   0.25
# P295   0.2
# P296   0.2
# P297   0.2
# P298   0.4
# P299   0.25
# P300   0.25
# P301   0.15
# P421   0.3
# P422   0.3
# P430   0.15
# P435   0.2
# P437   0.15
# P438   0.1
# P441   0.05
# P442   0.15
# P443   0.15
# P444   0.1
# P445   0.025
# P446   0.1
# P447   0.15
# P448   0.15
# P449   0.15
# P451   0.019
# P452   0.15
# P453   0.15
# P454   0.2
# P455   0.2
# P456   0.2
# P457   0.2
# P458   0.2
# P459   0.2
# P460   0.3
# P461   0.3
# P462   0.15
# P463   0.3
# P464   0.02
# P465   0.02
# P466   0.3
# P467   0.3
# P468   0.025
# P469   0.025
# P471   0.1
# P472   0.1
# P473   0.1
# P474   0.05
# P475   0.05
# P476   0.15
# P477   0.15
# P478   0.3
# P479   0.3
# P480   0.3
# P481   0.15
# P482   0.15
# P483   0.3
# P484   0.3
# P485   0.3
# P486   0.3
# P488   0.25
# P489   0.25
# P490   0.25
# P491   0.25
# P492   0.15
# P493   0.15
# P494   0.15
# P495   0.15
# P496   0.032
# P497   0.032
# P498   0.15
# P499   0.15
# P500   0.15
# P501   0.15
# P502   0.15
# P503   0.15
# P504   0.15
# P505   0.15
# P506   0.15
# P507   0.15
# P508   0.15
# P509   0.1
# P510   0.1
# P511   0.3
# P512   0.3
# P513   0.3
# P514   0.3
# P516   0.15
# P517   0.15
# P518   0.15
# P520   0.3
# P521   0.3
# P523   0.15
# P524   0.15
# P525   0.3
# P526   0.3
# P527   0.3
# P528   0.3
# P529   0.2
# P530   0.2
# P531   0.3
# P532   0.3
# P533   0.3
# P534   0.3
# P535   0.15
# P536   0.25
# P538   0.15
# P539   0.15
# P544   0.15
# P546   0.15
# P548   0.25
# P549   0.25
# P551   0.15
# P553   0.02

# %%
pipe_diameter = wn.query_link_attribute('diameter')

# %%
pipe_diameter
# Out:
# P2       0.25
# P3       0.25
# P4       0.25
# P5       0.25
# P7       0.25
#          ...
# P551     0.15
# P553     0.02
# FCV51    0.15
# FCV63    0.15
# FCV72    0.15
# Length: 361, dtype: float64

# %%
# przed nową symulacją
wn.reset_initial_values()

# %%
for control_name, control in wn.controls():
    print(control_name, " ", control)
# Out:
# control 1   Control  := if sim_time = 0.0 sec then set FCValve('FCV63').status to Closed with priority 3
# control 2   Control  := if Tank('T1').level <= 22.32 then set FCValve('FCV51').status to Open with priority 3
# control 3   Control  := if Tank('T1').level >= 26.21 then set FCValve('FCV51').status to Closed with priority 3
# control 4   Control  := if Tank('T2').level <= 15.85 then set FCValve('FCV72').status to Open with priority 3
# control 5   Control  := if Tank('T2').level >= 20.21 then set FCValve('FCV72').status to Closed with priority 3

# %%
for pump_name, pump in wn.pumps():
    print(pump_name, " ", pump)
# Out:
# PMP51   PMP51
# PMP63   PMP63
# PMP72   PMP72
