# %% [markdown]
# ## External imports

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ## Internal libraries imports

# %%
import wntr_WSN
import networkx_graph as ng
import linear_regression as lr

# %% [markdown]
# ## Input data

# %%
method = 'method'                              # for file naming
leak_node = 'J64'                             # node that's leaking
comment = ''                                   # last word(s) in output filename
leak_start = 48                                # in hours
leak_end = 73                                  # in hours
leak_area = 0.0005
sim_duration = 130                             # total duration of the simulation

# %% [markdown]
# ## Model each node with linear regression

# %%
linreg_models, normalization_params = lr.model_network_with_linreg(n=3)
# Out:
# Modeling the network with linreg (linear_regression.py - model_network_with_linregression())
# Creating a NetworkX graph from .inp file (networkx_graph.py - create_graph())
# Running the simulation (wntr_WSN.py - get_sim_results())
# c:\users\pc\anaconda3\envs\wodociagi\lib\site-packages\scipy\optimize\minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# 	Modeling junction J1: (1 out of 309)
# 	Modeling junction J2: (2 out of 309)
# 	Modeling junction J3: (3 out of 309)
# 	Modeling junction J4: (4 out of 309)
# 	Modeling junction J5: (5 out of 309)
# 	Modeling junction J6: (6 out of 309)
# 	Modeling junction J7: (7 out of 309)
# 	Modeling junction J8: (8 out of 309)
# 	Modeling junction J9: (9 out of 309)
# 	Modeling junction J10: (10 out of 309)
# 	Modeling junction J11: (11 out of 309)
# 	Modeling junction J12: (12 out of 309)
# 	Modeling junction J13: (13 out of 309)
# 	Modeling junction J14: (14 out of 309)
# 	Modeling junction J15: (15 out of 309)
# 	Modeling junction J16: (16 out of 309)
# 	Modeling junction J17: (17 out of 309)
# 	Modeling junction J18: (18 out of 309)
# 	Modeling junction J19: (19 out of 309)
# 	Modeling junction J20: (20 out of 309)
# 	Modeling junction J21: (21 out of 309)
# 	Modeling junction J22: (22 out of 309)
# 	Modeling junction J24: (23 out of 309)
# 	Modeling junction J25: (24 out of 309)
# 	Modeling junction J26: (25 out of 309)
# 	Modeling junction J27: (26 out of 309)
# 	Modeling junction J28: (27 out of 309)
# 	Modeling junction J29: (28 out of 309)
# 	Modeling junction J30: (29 out of 309)
# 	Modeling junction J31: (30 out of 309)
# 	Modeling junction J32: (31 out of 309)
# 	Modeling junction J33: (32 out of 309)
# 	Modeling junction J34: (33 out of 309)
# 	Modeling junction J35: (34 out of 309)
# 	Modeling junction J36: (35 out of 309)
# 	Modeling junction J37: (36 out of 309)
# 	Modeling junction J38: (37 out of 309)
# 	Modeling junction J39: (38 out of 309)
# 	Modeling junction J40: (39 out of 309)
# 	Modeling junction J41: (40 out of 309)
# 	Modeling junction J42: (41 out of 309)
# 	Modeling junction J43: (42 out of 309)
# 	Modeling junction J44: (43 out of 309)
# 	Modeling junction J45: (44 out of 309)
# 	Modeling junction J46: (45 out of 309)
# 	Modeling junction J47: (46 out of 309)
# 	Modeling junction J48: (47 out of 309)
# 	Modeling junction J49: (48 out of 309)
# 	Modeling junction J50: (49 out of 309)
# 	Modeling junction J52: (50 out of 309)
# 	Modeling junction J53: (51 out of 309)
# 	Modeling junction J54: (52 out of 309)
# 	Modeling junction J56: (53 out of 309)
# 	Modeling junction J57: (54 out of 309)
# 	Modeling junction J58: (55 out of 309)
# 	Modeling junction J59: (56 out of 309)
# 	Modeling junction J60: (57 out of 309)
# 	Modeling junction J61: (58 out of 309)
# 	Modeling junction J62: (59 out of 309)
# 	Modeling junction J63: (60 out of 309)
# 	Modeling junction J64: (61 out of 309)
# 	Modeling junction J65: (62 out of 309)
# 	Modeling junction J66: (63 out of 309)
# 	Modeling junction J67: (64 out of 309)
# 	Modeling junction J68: (65 out of 309)
# 	Modeling junction J69: (66 out of 309)
# 	Modeling junction J70: (67 out of 309)
# 	Modeling junction J71: (68 out of 309)
# 	Modeling junction J72: (69 out of 309)
# 	Modeling junction J73: (70 out of 309)
# 	Modeling junction J75: (71 out of 309)
# 	Modeling junction J76: (72 out of 309)
# 	Modeling junction J77: (73 out of 309)
# 	Modeling junction J78: (74 out of 309)
# 	Modeling junction J79: (75 out of 309)
# 	Modeling junction J80: (76 out of 309)
# 	Modeling junction J81: (77 out of 309)
# 	Modeling junction J82: (78 out of 309)
# 	Modeling junction J83: (79 out of 309)
# 	Modeling junction J84: (80 out of 309)
# 	Modeling junction J85: (81 out of 309)
# 	Modeling junction J86: (82 out of 309)
# 	Modeling junction J87: (83 out of 309)
# 	Modeling junction J88: (84 out of 309)
# 	Modeling junction J89: (85 out of 309)
# 	Modeling junction J90: (86 out of 309)
# 	Modeling junction J91: (87 out of 309)
# 	Modeling junction J92: (88 out of 309)
# 	Modeling junction J93: (89 out of 309)
# 	Modeling junction J94: (90 out of 309)
# 	Modeling junction J95: (91 out of 309)
# 	Modeling junction J96: (92 out of 309)
# 	Modeling junction J97: (93 out of 309)
# 	Modeling junction J98: (94 out of 309)
# 	Modeling junction J99: (95 out of 309)
# 	Modeling junction J100: (96 out of 309)
# 	Modeling junction J102: (97 out of 309)
# 	Modeling junction J103: (98 out of 309)
# 	Modeling junction J104: (99 out of 309)
# 	Modeling junction J105: (100 out of 309)
# 	Modeling junction J106: (101 out of 309)
# 	Modeling junction J107: (102 out of 309)
# 	Modeling junction J108: (103 out of 309)
# 	Modeling junction J109: (104 out of 309)
# 	Modeling junction J110: (105 out of 309)
# 	Modeling junction J111: (106 out of 309)
# 	Modeling junction J112: (107 out of 309)
# 	Modeling junction J113: (108 out of 309)
# 	Modeling junction J114: (109 out of 309)
# 	Modeling junction J115: (110 out of 309)
# 	Modeling junction J116: (111 out of 309)
# 	Modeling junction J117: (112 out of 309)
# 	Modeling junction J118: (113 out of 309)
# 	Modeling junction J119: (114 out of 309)
# 	Modeling junction J120: (115 out of 309)
# 	Modeling junction J121: (116 out of 309)
# 	Modeling junction J122: (117 out of 309)
# 	Modeling junction J123: (118 out of 309)
# 	Modeling junction J124: (119 out of 309)
# 	Modeling junction J125: (120 out of 309)
# 	Modeling junction J126: (121 out of 309)
# 	Modeling junction J127: (122 out of 309)
# 	Modeling junction J128: (123 out of 309)
# 	Modeling junction J129: (124 out of 309)
# 	Modeling junction J130: (125 out of 309)
# 	Modeling junction J131: (126 out of 309)
# 	Modeling junction J132: (127 out of 309)
# 	Modeling junction J133: (128 out of 309)
# 	Modeling junction J134: (129 out of 309)
# 	Modeling junction J135: (130 out of 309)
# 	Modeling junction J136: (131 out of 309)
# 	Modeling junction J137: (132 out of 309)
# 	Modeling junction J138: (133 out of 309)
# 	Modeling junction J139: (134 out of 309)
# 	Modeling junction J140: (135 out of 309)
# 	Modeling junction J141: (136 out of 309)
# 	Modeling junction J142: (137 out of 309)
# 	Modeling junction J143: (138 out of 309)
# 	Modeling junction J144: (139 out of 309)
# 	Modeling junction J145: (140 out of 309)
# 	Modeling junction J146: (141 out of 309)
# 	Modeling junction J147: (142 out of 309)
# 	Modeling junction J148: (143 out of 309)
# 	Modeling junction J149: (144 out of 309)
# 	Modeling junction J150: (145 out of 309)
# 	Modeling junction J151: (146 out of 309)
# 	Modeling junction J153: (147 out of 309)
# 	Modeling junction J154: (148 out of 309)
# 	Modeling junction J155: (149 out of 309)
# 	Modeling junction J156: (150 out of 309)
# 	Modeling junction J157: (151 out of 309)
# 	Modeling junction J158: (152 out of 309)
# 	Modeling junction J159: (153 out of 309)
# 	Modeling junction J160: (154 out of 309)
# 	Modeling junction J161: (155 out of 309)
# 	Modeling junction J162: (156 out of 309)
# 	Modeling junction J163: (157 out of 309)
# 	Modeling junction J164: (158 out of 309)
# 	Modeling junction J165: (159 out of 309)
# 	Modeling junction J166: (160 out of 309)
# 	Modeling junction J167: (161 out of 309)
# 	Modeling junction J168: (162 out of 309)
# 	Modeling junction J169: (163 out of 309)
# 	Modeling junction J170: (164 out of 309)
# 	Modeling junction J171: (165 out of 309)
# 	Modeling junction J172: (166 out of 309)
# 	Modeling junction J173: (167 out of 309)
# 	Modeling junction J175: (168 out of 309)
# 	Modeling junction J176: (169 out of 309)
# 	Modeling junction J177: (170 out of 309)
# 	Modeling junction J179: (171 out of 309)
# 	Modeling junction J180: (172 out of 309)
# 	Modeling junction J181: (173 out of 309)
# 	Modeling junction J182: (174 out of 309)
# 	Modeling junction J183: (175 out of 309)
# 	Modeling junction J184: (176 out of 309)
# 	Modeling junction J185: (177 out of 309)
# 	Modeling junction J186: (178 out of 309)
# 	Modeling junction J187: (179 out of 309)
# 	Modeling junction J188: (180 out of 309)
# 	Modeling junction J189: (181 out of 309)
# 	Modeling junction J190: (182 out of 309)
# 	Modeling junction J191: (183 out of 309)
# 	Modeling junction J192: (184 out of 309)
# 	Modeling junction J193: (185 out of 309)
# 	Modeling junction J194: (186 out of 309)
# 	Modeling junction J195: (187 out of 309)
# 	Modeling junction J196: (188 out of 309)
# 	Modeling junction J197: (189 out of 309)
# 	Modeling junction J198: (190 out of 309)
# 	Modeling junction J199: (191 out of 309)
# 	Modeling junction J200: (192 out of 309)
# 	Modeling junction J202: (193 out of 309)
# 	Modeling junction J203: (194 out of 309)
# 	Modeling junction J204: (195 out of 309)
# 	Modeling junction J205: (196 out of 309)
# 	Modeling junction J206: (197 out of 309)
# 	Modeling junction J207: (198 out of 309)
# 	Modeling junction J208: (199 out of 309)
# 	Modeling junction J209: (200 out of 309)
# 	Modeling junction J210: (201 out of 309)
# 	Modeling junction J211: (202 out of 309)
# 	Modeling junction J212: (203 out of 309)
# 	Modeling junction J213: (204 out of 309)
# 	Modeling junction J214: (205 out of 309)
# 	Modeling junction J216: (206 out of 309)
# 	Modeling junction J218: (207 out of 309)
# 	Modeling junction J219: (208 out of 309)
# 	Modeling junction J220: (209 out of 309)
# 	Modeling junction J223: (210 out of 309)
# 	Modeling junction J224: (211 out of 309)
# 	Modeling junction J225: (212 out of 309)
# 	Modeling junction J226: (213 out of 309)
# 	Modeling junction J227: (214 out of 309)
# 	Modeling junction J228: (215 out of 309)
# 	Modeling junction J229: (216 out of 309)
# 	Modeling junction J230: (217 out of 309)
# 	Modeling junction J231: (218 out of 309)
# 	Modeling junction J232: (219 out of 309)
# 	Modeling junction J233: (220 out of 309)
# 	Modeling junction J235: (221 out of 309)
# 	Modeling junction J236: (222 out of 309)
# 	Modeling junction J239: (223 out of 309)
# 	Modeling junction J240: (224 out of 309)
# 	Modeling junction J241: (225 out of 309)
# 	Modeling junction J242: (226 out of 309)
# 	Modeling junction J243: (227 out of 309)
# 	Modeling junction J244: (228 out of 309)
# 	Modeling junction J245: (229 out of 309)
# 	Modeling junction J246: (230 out of 309)
# 	Modeling junction J247: (231 out of 309)
# 	Modeling junction J248: (232 out of 309)
# 	Modeling junction J249: (233 out of 309)
# 	Modeling junction J250: (234 out of 309)
# 	Modeling junction J251: (235 out of 309)
# 	Modeling junction J252: (236 out of 309)
# 	Modeling junction J253: (237 out of 309)
# 	Modeling junction J254: (238 out of 309)
# 	Modeling junction J256: (239 out of 309)
# 	Modeling junction J257: (240 out of 309)
# 	Modeling junction J258: (241 out of 309)
# 	Modeling junction J259: (242 out of 309)
# 	Modeling junction J260: (243 out of 309)
# 	Modeling junction J261: (244 out of 309)
# 	Modeling junction J262: (245 out of 309)
# 	Modeling junction J263: (246 out of 309)
# 	Modeling junction J264: (247 out of 309)
# 	Modeling junction J265: (248 out of 309)
# 	Modeling junction J267: (249 out of 309)
# 	Modeling junction J269: (250 out of 309)
# 	Modeling junction J273: (251 out of 309)
# 	Modeling junction J274: (252 out of 309)
# 	Modeling junction J275: (253 out of 309)
# 	Modeling junction J276: (254 out of 309)
# 	Modeling junction J277: (255 out of 309)
# 	Modeling junction J278: (256 out of 309)
# 	Modeling junction J279: (257 out of 309)
# 	Modeling junction J280: (258 out of 309)
# 	Modeling junction J281: (259 out of 309)
# 	Modeling junction J282: (260 out of 309)
# 	Modeling junction J283: (261 out of 309)
# 	Modeling junction J284: (262 out of 309)
# 	Modeling junction J285: (263 out of 309)
# 	Modeling junction J286: (264 out of 309)
# 	Modeling junction J287: (265 out of 309)
# 	Modeling junction J288: (266 out of 309)
# 	Modeling junction J289: (267 out of 309)
# 	Modeling junction J290: (268 out of 309)
# 	Modeling junction J291: (269 out of 309)
# 	Modeling junction J292: (270 out of 309)
# 	Modeling junction J293: (271 out of 309)
# 	Modeling junction J294: (272 out of 309)
# 	Modeling junction J295: (273 out of 309)
# 	Modeling junction J296: (274 out of 309)
# 	Modeling junction J297: (275 out of 309)
# 	Modeling junction J298: (276 out of 309)
# 	Modeling junction J299: (277 out of 309)
# 	Modeling junction J300: (278 out of 309)
# 	Modeling junction J301: (279 out of 309)
# 	Modeling junction J302: (280 out of 309)
# 	Modeling junction J303: (281 out of 309)
# 	Modeling junction J304: (282 out of 309)
# 	Modeling junction J305: (283 out of 309)
# 	Modeling junction J306: (284 out of 309)
# 	Modeling junction J307: (285 out of 309)
# 	Modeling junction J308: (286 out of 309)
# 	Modeling junction J309: (287 out of 309)
# 	Modeling junction J310: (288 out of 309)
# 	Modeling junction J311: (289 out of 309)
# 	Modeling junction J312: (290 out of 309)
# 	Modeling junction J313: (291 out of 309)
# 	Modeling junction J314: (292 out of 309)
# 	Modeling junction J315: (293 out of 309)
# 	Modeling junction J316: (294 out of 309)
# 	Modeling junction J317: (295 out of 309)
# 	Modeling junction J318: (296 out of 309)
# 	Modeling junction J319: (297 out of 309)
# 	Modeling junction J320: (298 out of 309)
# 	Modeling junction J321: (299 out of 309)
# 	Modeling junction J322: (300 out of 309)
# 	Modeling junction J323: (301 out of 309)
# 	Modeling junction J324: (302 out of 309)
# 	Modeling junction J326: (303 out of 309)
# 	Modeling junction J327: (304 out of 309)
# 	Modeling junction J539: (305 out of 309)
# 	Modeling junction J544: (306 out of 309)
# 	Modeling junction J546: (307 out of 309)
# 	Modeling junction T1: (308 out of 309)
# 	Modeling junction T2: (309 out of 309)

# %%
linreg_models
# Out:
# [{'node': 'J1',
#   'linreg': LinearRegression(),
#   'msq': 0.0003094505413836043,
#   'r2': 0.999779023346383,
#   'sensors': ['J284', 'P9', 'P460']},
#  {'node': 'J2',
#   'linreg': LinearRegression(),
#   'msq': 2.2718571746158296e-05,
#   'r2': 0.9999860527644338,
#   'sensors': ['J284', 'P460', 'P9']},
#  {'node': 'J3',
#   'linreg': LinearRegression(),
#   'msq': 2.4049235727063265e-05,
#   'r2': 0.9999835140029287,
#   'sensors': ['J284', 'P460', 'P9']},
#  {'node': 'J4',
#   'linreg': LinearRegression(),
#   'msq': 8.979415354764518e-05,
#   'r2': 0.9999437589457921,
#   'sensors': ['J284', 'P460', 'P9']},
#  {'node': 'J5',
#   'linreg': LinearRegression(),
#   'msq': 6.921094605668927e-05,
#   'r2': 0.9999575212346724,
#   'sensors': ['J284', 'P460', 'P9']},
#  {'node': 'J6',
#   'linreg': LinearRegression(),
#   'msq': 0.001315916827095419,
#   'r2': 0.9993899974078964,
#   'sensors': ['P9', 'J79', 'P500']},
#  {'node': 'J7',
#   'linreg': LinearRegression(),
#   'msq': 0.00027063805115237587,
#   'r2': 0.9998813887377228,
#   'sensors': ['J284', 'P9', 'P460']},
#  {'node': 'J8',
#   'linreg': LinearRegression(),
#   'msq': 0.00025383092036565904,
#   'r2': 0.9998484476306594,
#   'sensors': ['J284', 'P9', 'P460']},
#  {'node': 'J9',
#   'linreg': LinearRegression(),
#   'msq': 0.00031276677981475684,
#   'r2': 0.9998625916900282,
#   'sensors': ['J284', 'P9', 'P460']},
#  {'node': 'J10',
#   'linreg': LinearRegression(),
#   'msq': 0.000967601264886546,
#   'r2': 0.9994893211964133,
#   'sensors': ['P9', 'J79', 'P500']},
#  {'node': 'J11',
#   'linreg': LinearRegression(),
#   'msq': 0.0005484068847349475,
#   'r2': 0.9996674336502284,
#   'sensors': ['P9', 'J12', 'J79']},
#  {'node': 'J12',
#   'linreg': LinearRegression(),
#   'msq': 5.048709793414476e-29,
#   'r2': 1.0,
#   'sensors': ['J12', 'P9', 'P13']},
#  {'node': 'J13',
#   'linreg': LinearRegression(),
#   'msq': 9.996649036817023e-06,
#   'r2': 0.9999950194358924,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J14',
#   'linreg': LinearRegression(),
#   'msq': 3.483175393701755e-05,
#   'r2': 0.9999786597753552,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J15',
#   'linreg': LinearRegression(),
#   'msq': 1.0926223192945634e-06,
#   'r2': 0.999999399201519,
#   'sensors': ['P13', 'J17', 'J12']},
#  {'node': 'J16',
#   'linreg': LinearRegression(),
#   'msq': 5.200021502730398e-07,
#   'r2': 0.9999997178383436,
#   'sensors': ['P13', 'J17', 'J12']},
#  {'node': 'J17',
#   'linreg': LinearRegression(),
#   'msq': 5.048709793414476e-29,
#   'r2': 1.0,
#   'sensors': ['J17', 'P13', 'J12']},
#  {'node': 'J18',
#   'linreg': LinearRegression(),
#   'msq': 8.215422198335973e-06,
#   'r2': 0.9999952246654162,
#   'sensors': ['J17', 'P13', 'P536']},
#  {'node': 'J19',
#   'linreg': LinearRegression(),
#   'msq': 2.1712982609723712e-05,
#   'r2': 0.9999887174591027,
#   'sensors': ['J17', 'P536', 'P13']},
#  {'node': 'J20',
#   'linreg': LinearRegression(),
#   'msq': 2.380061830000289e-05,
#   'r2': 0.9999860933823945,
#   'sensors': ['J17', 'P536', 'P13']},
#  {'node': 'J21',
#   'linreg': LinearRegression(),
#   'msq': 4.474717566267128e-06,
#   'r2': 0.9999983454320741,
#   'sensors': ['P536', 'J163', 'J17']},
#  {'node': 'J22',
#   'linreg': LinearRegression(),
#   'msq': 8.047445567390268e-07,
#   'r2': 0.999999529794353,
#   'sensors': ['P536', 'J163', 'J17']},
#  {'node': 'J24',
#   'linreg': LinearRegression(),
#   'msq': 0.001344239201029277,
#   'r2': 0.9993863050755517,
#   'sensors': ['P539', 'J539', 'P460']},
#  {'node': 'J25',
#   'linreg': LinearRegression(),
#   'msq': 0.0004703120680675365,
#   'r2': 0.9998767758046666,
#   'sensors': ['P22', 'J316', 'J28']},
#  {'node': 'J26',
#   'linreg': LinearRegression(),
#   'msq': 7.455982471323399e-05,
#   'r2': 0.9999773284191099,
#   'sensors': ['P22', 'J28', 'J316']},
#  {'node': 'J27',
#   'linreg': LinearRegression(),
#   'msq': 9.450851838671285e-05,
#   'r2': 0.9999639369722124,
#   'sensors': ['P22', 'J28', 'J316']},
#  {'node': 'J28',
#   'linreg': LinearRegression(),
#   'msq': 5.048709793414476e-29,
#   'r2': 1.0,
#   'sensors': ['J28', 'P22', 'J316']},
#  {'node': 'J29',
#   'linreg': LinearRegression(),
#   'msq': 7.242931142569591e-05,
#   'r2': 0.999972856764367,
#   'sensors': ['J28', 'P22', 'P27']},
#  {'node': 'J30',
#   'linreg': LinearRegression(),
#   'msq': 0.0002447535290838555,
#   'r2': 0.9999190695352701,
#   'sensors': ['J28', 'P27', 'P22']},
#  {'node': 'J31',
#   'linreg': LinearRegression(),
#   'msq': 2.5537138877471384e-06,
#   'r2': 0.9999990302548533,
#   'sensors': ['P27', 'J33', 'J28']},
#  {'node': 'J32',
#   'linreg': LinearRegression(),
#   'msq': 7.049688047313418e-07,
#   'r2': 0.9999997140523526,
#   'sensors': ['P27', 'J33', 'J28']},
#  {'node': 'J33',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J33', 'P27', 'J151']},
#  {'node': 'J34',
#   'linreg': LinearRegression(),
#   'msq': 3.5314859182154094e-05,
#   'r2': 0.9999900855362918,
#   'sensors': ['J316', 'P22', 'P520']},
#  {'node': 'J35',
#   'linreg': LinearRegression(),
#   'msq': 9.274934037450648e-07,
#   'r2': 0.999999724147211,
#   'sensors': ['J316', 'P520', 'P22']},
#  {'node': 'J36',
#   'linreg': LinearRegression(),
#   'msq': 8.150771469279833e-06,
#   'r2': 0.9999969550047124,
#   'sensors': ['P520', 'J316', 'J39']},
#  {'node': 'J37',
#   'linreg': LinearRegression(),
#   'msq': 1.1017803536520094e-05,
#   'r2': 0.9999965245450793,
#   'sensors': ['P520', 'J316', 'J39']},
#  {'node': 'J38',
#   'linreg': LinearRegression(),
#   'msq': 8.038761426132093e-05,
#   'r2': 0.9999640228569393,
#   'sensors': ['P520', 'J39', 'P478']},
#  {'node': 'J39',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J40',
#   'linreg': LinearRegression(),
#   'msq': 2.341309032537044e-05,
#   'r2': 0.999990051810908,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J41',
#   'linreg': LinearRegression(),
#   'msq': 1.0386293560323352e-05,
#   'r2': 0.9999952096313989,
#   'sensors': ['P174', 'J172', 'J39']},
#  {'node': 'J42',
#   'linreg': LinearRegression(),
#   'msq': 2.597408250328944e-05,
#   'r2': 0.9999876819423837,
#   'sensors': ['J43', 'P174', 'P511']},
#  {'node': 'J43',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J43', 'P511', 'P46']},
#  {'node': 'J44',
#   'linreg': LinearRegression(),
#   'msq': 1.6557949198848845e-05,
#   'r2': 0.9999930122698921,
#   'sensors': ['J43', 'P511', 'P46']},
#  {'node': 'J45',
#   'linreg': LinearRegression(),
#   'msq': 4.5749172626485926e-08,
#   'r2': 0.9999999772741769,
#   'sensors': ['P46', 'J62', 'P55']},
#  {'node': 'J46',
#   'linreg': LinearRegression(),
#   'msq': 1.969693376383129e-05,
#   'r2': 0.9999909803158696,
#   'sensors': ['J43', 'P511', 'P174']},
#  {'node': 'J47',
#   'linreg': LinearRegression(),
#   'msq': 2.4760331993319954e-05,
#   'r2': 0.9999873990027696,
#   'sensors': ['J172', 'J43', 'P511']},
#  {'node': 'J48',
#   'linreg': LinearRegression(),
#   'msq': 1.9146040974762316e-05,
#   'r2': 0.9999894274155003,
#   'sensors': ['J172', 'P174', 'J43']},
#  {'node': 'J49',
#   'linreg': LinearRegression(),
#   'msq': 1.2123438565381882e-05,
#   'r2': 0.9999957688989652,
#   'sensors': ['J137', 'P43', 'J33']},
#  {'node': 'J50',
#   'linreg': LinearRegression(),
#   'msq': 0.00018843046168956666,
#   'r2': 0.9999252650610226,
#   'sensors': ['J137', 'P43', 'J33']},
#  {'node': 'J52',
#   'linreg': LinearRegression(),
#   'msq': 5.048709793414476e-29,
#   'r2': 1.0,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J53',
#   'linreg': LinearRegression(),
#   'msq': 2.7661034194382057e-14,
#   'r2': 0.9999999999999892,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J54',
#   'linreg': LinearRegression(),
#   'msq': 2.7480319128711703e-29,
#   'r2': 1.0,
#   'sensors': ['J54', 'P46', 'J62']},
#  {'node': 'J56',
#   'linreg': LinearRegression(),
#   'msq': 1.0359445957261123e-09,
#   'r2': 0.9999999994157706,
#   'sensors': ['P52', 'J60', 'J54']},
#  {'node': 'J57',
#   'linreg': LinearRegression(),
#   'msq': 3.661074497767976e-10,
#   'r2': 0.9999999997620511,
#   'sensors': ['P52', 'J60', 'J54']},
#  {'node': 'J58',
#   'linreg': LinearRegression(),
#   'msq': 4.58141664203778e-11,
#   'r2': 0.9999999999694438,
#   'sensors': ['P52', 'J60', 'J54']},
#  {'node': 'J59',
#   'linreg': LinearRegression(),
#   'msq': 3.6219603706453107e-11,
#   'r2': 0.9999999999750315,
#   'sensors': ['P52', 'J60', 'J54']},
#  {'node': 'J60',
#   'linreg': LinearRegression(),
#   'msq': 5.048709793414476e-29,
#   'r2': 1.0,
#   'sensors': ['J60', 'P52', 'P520']},
#  {'node': 'J61',
#   'linreg': LinearRegression(),
#   'msq': 1.6526170816113934e-11,
#   'r2': 0.9999999999887017,
#   'sensors': ['J60', 'P52', 'P520']},
#  {'node': 'J62',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J62', 'P55', 'P204']},
#  {'node': 'J63',
#   'linreg': LinearRegression(),
#   'msq': 2.738329496805738e-08,
#   'r2': 0.9999999867357642,
#   'sensors': ['P56', 'J64', 'J62']},
#  {'node': 'J64',
#   'linreg': LinearRegression(),
#   'msq': 5.048709793414476e-29,
#   'r2': 1.0,
#   'sensors': ['J64', 'P56', 'J129']},
#  {'node': 'J65',
#   'linreg': LinearRegression(),
#   'msq': 1.306926291360694e-07,
#   'r2': 0.9999999427983561,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J66',
#   'linreg': LinearRegression(),
#   'msq': 5.986539301629791e-05,
#   'r2': 0.999972402593206,
#   'sensors': ['J52', 'P45', 'J67']},
#  {'node': 'J67',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J67', 'P459', 'J79']},
#  {'node': 'J68',
#   'linreg': LinearRegression(),
#   'msq': 1.63270435436336e-08,
#   'r2': 0.9999999936950821,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J69',
#   'linreg': LinearRegression(),
#   'msq': 1.542261073017471e-07,
#   'r2': 0.9999999351382833,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J70',
#   'linreg': LinearRegression(),
#   'msq': 7.652817355353378e-05,
#   'r2': 0.999972532717188,
#   'sensors': ['J33', 'J151', 'P213']},
#  {'node': 'J71',
#   'linreg': LinearRegression(),
#   'msq': 6.074294186869159e-05,
#   'r2': 0.9999768587382079,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J72',
#   'linreg': LinearRegression(),
#   'msq': 3.3936046208056114e-05,
#   'r2': 0.9999843631617031,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J73',
#   'linreg': LinearRegression(),
#   'msq': 2.761208637188742e-05,
#   'r2': 0.9999868950443915,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J75',
#   'linreg': LinearRegression(),
#   'msq': 0.0004920381264396507,
#   'r2': 0.9997624474931932,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J76',
#   'linreg': LinearRegression(),
#   'msq': 0.00022123445651693212,
#   'r2': 0.9999016598670031,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J77',
#   'linreg': LinearRegression(),
#   'msq': 6.807566774882057e-05,
#   'r2': 0.9999645909462678,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J78',
#   'linreg': LinearRegression(),
#   'msq': 6.000400787448541e-06,
#   'r2': 0.9999966849337295,
#   'sensors': ['J67', 'P459', 'J79']},
#  {'node': 'J79',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J80',
#   'linreg': LinearRegression(),
#   'msq': 2.6389481979971035e-07,
#   'r2': 0.9999998641336237,
#   'sensors': ['J79', 'P500', 'J67']},
#  {'node': 'J81',
#   'linreg': LinearRegression(),
#   'msq': 0.0004853892451705881,
#   'r2': 0.9997681738830559,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J82',
#   'linreg': LinearRegression(),
#   'msq': 0.00038742771930648506,
#   'r2': 0.9998615227023512,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J83',
#   'linreg': LinearRegression(),
#   'msq': 0.00048677361871871273,
#   'r2': 0.9997450444132178,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J84',
#   'linreg': LinearRegression(),
#   'msq': 0.0007524665196843946,
#   'r2': 0.9996546519505071,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J85',
#   'linreg': LinearRegression(),
#   'msq': 0.0005603066815644632,
#   'r2': 0.9996672123097808,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J86',
#   'linreg': LinearRegression(),
#   'msq': 0.0004615575009067705,
#   'r2': 0.9997128219543098,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J87',
#   'linreg': LinearRegression(),
#   'msq': 2.128228276735326e-05,
#   'r2': 0.999989725619763,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J88',
#   'linreg': LinearRegression(),
#   'msq': 2.4586056543202752e-05,
#   'r2': 0.9999838142540389,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J89',
#   'linreg': LinearRegression(),
#   'msq': 3.0211744221270188e-05,
#   'r2': 0.9999851337384364,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J90',
#   'linreg': LinearRegression(),
#   'msq': 2.2153940956599702e-05,
#   'r2': 0.9999902980172007,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J91',
#   'linreg': LinearRegression(),
#   'msq': 2.653365071394493e-05,
#   'r2': 0.9999860680913212,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J92',
#   'linreg': LinearRegression(),
#   'msq': 1.73626627887566e-05,
#   'r2': 0.999989718326059,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J93',
#   'linreg': LinearRegression(),
#   'msq': 2.3593782483951216e-05,
#   'r2': 0.9999886983816298,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J94',
#   'linreg': LinearRegression(),
#   'msq': 2.7355506703232603e-05,
#   'r2': 0.9999868966962034,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J95',
#   'linreg': LinearRegression(),
#   'msq': 5.9331022199334736e-08,
#   'r2': 0.9999999724915982,
#   'sensors': ['J12', 'P9', 'P13']},
#  {'node': 'J96',
#   'linreg': LinearRegression(),
#   'msq': 5.309668704688895e-06,
#   'r2': 0.9999980420153904,
#   'sensors': ['P13', 'J17', 'J67']},
#  {'node': 'J97',
#   'linreg': LinearRegression(),
#   'msq': 0.00035466851793021417,
#   'r2': 0.9998272250419779,
#   'sensors': ['P13', 'J67', 'P459']},
#  {'node': 'J98',
#   'linreg': LinearRegression(),
#   'msq': 0.00017560875197262645,
#   'r2': 0.9999006489881112,
#   'sensors': ['P13', 'J67', 'P459']},
#  {'node': 'J99',
#   'linreg': LinearRegression(),
#   'msq': 0.00022238984588480244,
#   'r2': 0.9998791159674647,
#   'sensors': ['J67', 'P459', 'P13']},
#  {'node': 'J100',
#   'linreg': LinearRegression(),
#   'msq': 0.00016517599050054366,
#   'r2': 0.9999284166886067,
#   'sensors': ['J67', 'P459', 'P13']},
#  {'node': 'J102',
#   'linreg': LinearRegression(),
#   'msq': 0.0001785776938072101,
#   'r2': 0.9999041680781081,
#   'sensors': ['J67', 'P459', 'P536']},
#  {'node': 'J103',
#   'linreg': LinearRegression(),
#   'msq': 3.021286957296424e-05,
#   'r2': 0.9999860682382572,
#   'sensors': ['J67', 'P459', 'J163']},
#  {'node': 'J104',
#   'linreg': LinearRegression(),
#   'msq': 1.9080180027920025e-05,
#   'r2': 0.9999899143967654,
#   'sensors': ['J163', 'P536', 'J172']},
#  {'node': 'J105',
#   'linreg': LinearRegression(),
#   'msq': 9.697300368099563e-06,
#   'r2': 0.9999952349201447,
#   'sensors': ['J172', 'J163', 'P174']},
#  {'node': 'J106',
#   'linreg': LinearRegression(),
#   'msq': 1.3157605087875871e-05,
#   'r2': 0.9999946465665996,
#   'sensors': ['J172', 'P174', 'J163']},
#  {'node': 'J107',
#   'linreg': LinearRegression(),
#   'msq': 1.5411947363498066e-05,
#   'r2': 0.999991522314046,
#   'sensors': ['J172', 'P174', 'J43']},
#  {'node': 'J108',
#   'linreg': LinearRegression(),
#   'msq': 4.571135967340238e-05,
#   'r2': 0.9999751829441477,
#   'sensors': ['J67', 'P459', 'J151']},
#  {'node': 'J109',
#   'linreg': LinearRegression(),
#   'msq': 9.149234541168969e-05,
#   'r2': 0.9999654218219229,
#   'sensors': ['J67', 'P459', 'J151']},
#  {'node': 'J110',
#   'linreg': LinearRegression(),
#   'msq': 0.0008402155446009716,
#   'r2': 0.999644897630201,
#   'sensors': ['J151', 'P213', 'J67']},
#  {'node': 'J111',
#   'linreg': LinearRegression(),
#   'msq': 0.0017742277831137498,
#   'r2': 0.9991663296527359,
#   'sensors': ['J151', 'P213', 'J113']},
#  {'node': 'J112',
#   'linreg': LinearRegression(),
#   'msq': 1.5801186667772643e-05,
#   'r2': 0.9999938076937248,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J113',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J114',
#   'linreg': LinearRegression(),
#   'msq': 1.7184292322373657e-05,
#   'r2': 0.9999926430013888,
#   'sensors': ['J113', 'P110', 'J39']},
#  {'node': 'J115',
#   'linreg': LinearRegression(),
#   'msq': 0.00013176046973010404,
#   'r2': 0.9999270764941358,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J116',
#   'linreg': LinearRegression(),
#   'msq': 3.3386681369535347e-05,
#   'r2': 0.9999841491751876,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J117',
#   'linreg': LinearRegression(),
#   'msq': 3.228497121274496e-05,
#   'r2': 0.9999815515183552,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J118',
#   'linreg': LinearRegression(),
#   'msq': 0.00010806236239460373,
#   'r2': 0.999949176696505,
#   'sensors': ['J172', 'P174', 'J43']},
#  {'node': 'J119',
#   'linreg': LinearRegression(),
#   'msq': 5.195731706830594e-06,
#   'r2': 0.9999977189424392,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J120',
#   'linreg': LinearRegression(),
#   'msq': 2.4829818524125973e-05,
#   'r2': 0.9999883396906001,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J121',
#   'linreg': LinearRegression(),
#   'msq': 2.127777714013021e-06,
#   'r2': 0.9999991729743282,
#   'sensors': ['P174', 'J172', 'J39']},
#  {'node': 'J122',
#   'linreg': LinearRegression(),
#   'msq': 2.704397754330465e-06,
#   'r2': 0.9999986305045072,
#   'sensors': ['P174', 'J172', 'J39']},
#  {'node': 'J123',
#   'linreg': LinearRegression(),
#   'msq': 4.371526028702894e-08,
#   'r2': 0.9999999754153427,
#   'sensors': ['P56', 'J54', 'J64']},
#  {'node': 'J124',
#   'linreg': LinearRegression(),
#   'msq': 4.731518000862999e-08,
#   'r2': 0.9999999668702495,
#   'sensors': ['P56', 'J54', 'J64']},
#  {'node': 'J125',
#   'linreg': LinearRegression(),
#   'msq': 4.5162991585660086e-08,
#   'r2': 0.9999999773996789,
#   'sensors': ['P56', 'J54', 'J64']},
#  {'node': 'J126',
#   'linreg': LinearRegression(),
#   'msq': 8.405321986057694e-08,
#   'r2': 0.9999999606283742,
#   'sensors': ['P56', 'J54', 'J64']},
#  {'node': 'J127',
#   'linreg': LinearRegression(),
#   'msq': 3.615100456573543e-10,
#   'r2': 0.999999999779467,
#   'sensors': ['P244', 'J129', 'J207']},
#  {'node': 'J128',
#   'linreg': LinearRegression(),
#   'msq': 5.568907803918457e-10,
#   'r2': 0.9999999995740728,
#   'sensors': ['P244', 'J129', 'J207']},
#  {'node': 'J129',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J129', 'P244', 'J64']},
#  {'node': 'J130',
#   'linreg': LinearRegression(),
#   'msq': 4.401532292806226e-10,
#   'r2': 0.9999999997907855,
#   'sensors': ['J129', 'P244', 'J64']},
#  {'node': 'J131',
#   'linreg': LinearRegression(),
#   'msq': 4.70244082005889e-13,
#   'r2': 0.9999999999997008,
#   'sensors': ['J60', 'P52', 'P520']},
#  {'node': 'J132',
#   'linreg': LinearRegression(),
#   'msq': 4.934000124674556e-10,
#   'r2': 0.9999999998428051,
#   'sensors': ['J28', 'P22', 'J316']},
#  {'node': 'J133',
#   'linreg': LinearRegression(),
#   'msq': 7.832850957115586e-05,
#   'r2': 0.9999750255374282,
#   'sensors': ['J28', 'P22', 'P27']},
#  {'node': 'J134',
#   'linreg': LinearRegression(),
#   'msq': 0.0003095097491859559,
#   'r2': 0.9998765205687736,
#   'sensors': ['J28', 'P27', 'P22']},
#  {'node': 'J135',
#   'linreg': LinearRegression(),
#   'msq': 1.29672905747933e-06,
#   'r2': 0.9999994844645388,
#   'sensors': ['P27', 'J33', 'J28']},
#  {'node': 'J136',
#   'linreg': LinearRegression(),
#   'msq': 1.4313702376931591e-06,
#   'r2': 0.9999994591146651,
#   'sensors': ['P27', 'J33', 'J28']},
#  {'node': 'J137',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J137', 'P43', 'J52']},
#  {'node': 'J138',
#   'linreg': LinearRegression(),
#   'msq': 4.779358598676585e-06,
#   'r2': 0.9999979474896441,
#   'sensors': ['J33', 'J137', 'P43']},
#  {'node': 'J139',
#   'linreg': LinearRegression(),
#   'msq': 0.0002814195437604446,
#   'r2': 0.9999117348951604,
#   'sensors': ['J33', 'J151', 'P213']},
#  {'node': 'J140',
#   'linreg': LinearRegression(),
#   'msq': 0.0006023113726631208,
#   'r2': 0.9997443515301468,
#   'sensors': ['J33', 'J151', 'P213']},
#  {'node': 'J141',
#   'linreg': LinearRegression(),
#   'msq': 8.505944606223703e-06,
#   'r2': 0.9999965284489745,
#   'sensors': ['J33', 'J146', 'P280']},
#  {'node': 'J142',
#   'linreg': LinearRegression(),
#   'msq': 3.219478244903574e-06,
#   'r2': 0.9999988624380457,
#   'sensors': ['J316', 'P520', 'J146']},
#  {'node': 'J143',
#   'linreg': LinearRegression(),
#   'msq': 1.4099884089692123e-06,
#   'r2': 0.9999994339067554,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J144',
#   'linreg': LinearRegression(),
#   'msq': 8.588691815950113e-07,
#   'r2': 0.9999996700958405,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J145',
#   'linreg': LinearRegression(),
#   'msq': 8.980850457932984e-07,
#   'r2': 0.9999997055866862,
#   'sensors': ['J146', 'P280', 'J33']},
#  {'node': 'J146',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J147',
#   'linreg': LinearRegression(),
#   'msq': 3.8659697681588794e-08,
#   'r2': 0.9999999866413876,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J148',
#   'linreg': LinearRegression(),
#   'msq': 8.772601938369866e-05,
#   'r2': 0.9999649176170667,
#   'sensors': ['J67', 'P459', 'J151']},
#  {'node': 'J149',
#   'linreg': LinearRegression(),
#   'msq': 7.560906729011211e-05,
#   'r2': 0.9999665462536836,
#   'sensors': ['J67', 'P459', 'J151']},
#  {'node': 'J150',
#   'linreg': LinearRegression(),
#   'msq': 4.930047713829576e-05,
#   'r2': 0.9999822943507852,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J151',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J153',
#   'linreg': LinearRegression(),
#   'msq': 8.861848159880964e-06,
#   'r2': 0.9999968425626624,
#   'sensors': ['J33', 'J146', 'P280']},
#  {'node': 'J154',
#   'linreg': LinearRegression(),
#   'msq': 9.516490232640812e-07,
#   'r2': 0.9999996650201399,
#   'sensors': ['J146', 'P280', 'J33']},
#  {'node': 'J155',
#   'linreg': LinearRegression(),
#   'msq': 1.1379810757523192e-06,
#   'r2': 0.9999996245799212,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J156',
#   'linreg': LinearRegression(),
#   'msq': 4.596539176642965e-05,
#   'r2': 0.9999845002434241,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J157',
#   'linreg': LinearRegression(),
#   'msq': 7.931569736042464e-05,
#   'r2': 0.9999691309446287,
#   'sensors': ['J146', 'P280', 'J113']},
#  {'node': 'J158',
#   'linreg': LinearRegression(),
#   'msq': 6.273222453410115e-05,
#   'r2': 0.999971143908286,
#   'sensors': ['J146', 'P280', 'J113']},
#  {'node': 'J159',
#   'linreg': LinearRegression(),
#   'msq': 7.517671150765822e-05,
#   'r2': 0.9999703268295954,
#   'sensors': ['J146', 'P280', 'J113']},
#  {'node': 'J160',
#   'linreg': LinearRegression(),
#   'msq': 2.9135292115944567e-05,
#   'r2': 0.9999830902079154,
#   'sensors': ['J43', 'P174', 'P511']},
#  {'node': 'J161',
#   'linreg': LinearRegression(),
#   'msq': 2.9137965542129806e-05,
#   'r2': 0.9999858024164527,
#   'sensors': ['J43', 'P174', 'P511']},
#  {'node': 'J162',
#   'linreg': LinearRegression(),
#   'msq': 5.949742161449265e-06,
#   'r2': 0.999995904995016,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J163',
#   'linreg': LinearRegression(),
#   'msq': 5.048709793414476e-29,
#   'r2': 1.0,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J164',
#   'linreg': LinearRegression(),
#   'msq': 2.0752485448719343e-05,
#   'r2': 0.9999904560508865,
#   'sensors': ['J163', 'P536', 'J172']},
#  {'node': 'J165',
#   'linreg': LinearRegression(),
#   'msq': 0.00010247466161095954,
#   'r2': 0.9999362377585138,
#   'sensors': ['J163', 'P536', 'J67']},
#  {'node': 'J166',
#   'linreg': LinearRegression(),
#   'msq': 6.998982083636653e-06,
#   'r2': 0.9999965862781034,
#   'sensors': ['P536', 'J163', 'J17']},
#  {'node': 'J167',
#   'linreg': LinearRegression(),
#   'msq': 6.790363734959225e-06,
#   'r2': 0.9999965189638003,
#   'sensors': ['P536', 'J163', 'J17']},
#  {'node': 'J168',
#   'linreg': LinearRegression(),
#   'msq': 1.3715671560067987e-06,
#   'r2': 0.9999994443905164,
#   'sensors': ['J67', 'P459', 'J79']},
#  {'node': 'J169',
#   'linreg': LinearRegression(),
#   'msq': 0.0002619620388547669,
#   'r2': 0.999865879757053,
#   'sensors': ['J67', 'P459', 'J172']},
#  {'node': 'J170',
#   'linreg': LinearRegression(),
#   'msq': 0.00023881378808216763,
#   'r2': 0.9998895160412041,
#   'sensors': ['J67', 'P459', 'J172']},
#  {'node': 'J171',
#   'linreg': LinearRegression(),
#   'msq': 2.2758648020466248e-05,
#   'r2': 0.9999899252742401,
#   'sensors': ['J172', 'P174', 'J67']},
#  {'node': 'J172',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J172', 'P174', 'J39']},
#  {'node': 'J173',
#   'linreg': LinearRegression(),
#   'msq': 0.000153571583355292,
#   'r2': 0.9999453392583657,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J175',
#   'linreg': LinearRegression(),
#   'msq': 3.3136624406882335e-07,
#   'r2': 0.9999998501098465,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J176',
#   'linreg': LinearRegression(),
#   'msq': 2.5098451365345562e-08,
#   'r2': 0.9999999924958849,
#   'sensors': ['J137', 'P43', 'J52']},
#  {'node': 'J177',
#   'linreg': LinearRegression(),
#   'msq': 1.728520579272681e-09,
#   'r2': 0.9999999992615488,
#   'sensors': ['J137', 'P43', 'J52']},
#  {'node': 'J179',
#   'linreg': LinearRegression(),
#   'msq': 0.06124940272460691,
#   'r2': 0.9830569244654552,
#   'sensors': ['J316', 'P22', 'P520']},
#  {'node': 'J180',
#   'linreg': LinearRegression(),
#   'msq': 0.0010979294788283807,
#   'r2': 0.9996328381221977,
#   'sensors': ['J146', 'P280', 'J316']},
#  {'node': 'J181',
#   'linreg': LinearRegression(),
#   'msq': 0.0011399183717909897,
#   'r2': 0.9996770013306597,
#   'sensors': ['J316', 'J146', 'P280']},
#  {'node': 'J182',
#   'linreg': LinearRegression(),
#   'msq': 0.0015869070006646416,
#   'r2': 0.9994950089417007,
#   'sensors': ['P520', 'J316', 'J146']},
#  {'node': 'J183',
#   'linreg': LinearRegression(),
#   'msq': 1.1804041710245325e-05,
#   'r2': 0.9999958536613037,
#   'sensors': ['P520', 'J316', 'J39']},
#  {'node': 'J184',
#   'linreg': LinearRegression(),
#   'msq': 3.60901409023244e-05,
#   'r2': 0.9999871009408673,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J185',
#   'linreg': LinearRegression(),
#   'msq': 0.0018663617144833477,
#   'r2': 0.9992876735153008,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J186',
#   'linreg': LinearRegression(),
#   'msq': 0.014230436836224904,
#   'r2': 0.9947814050466948,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J187',
#   'linreg': LinearRegression(),
#   'msq': 0.0008745789892500552,
#   'r2': 0.9997251208184567,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J188',
#   'linreg': LinearRegression(),
#   'msq': 6.420157175220146e-06,
#   'r2': 0.9999971171248861,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J189',
#   'linreg': LinearRegression(),
#   'msq': 0.8815971007243241,
#   'r2': 0.8119807751479047,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J190',
#   'linreg': LinearRegression(),
#   'msq': 0.8545628474459361,
#   'r2': 0.770963527923422,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J191',
#   'linreg': LinearRegression(),
#   'msq': 0.07722700440898325,
#   'r2': 0.9654358994682762,
#   'sensors': ['J163', 'P536', 'J67']},
#  {'node': 'J192',
#   'linreg': LinearRegression(),
#   'msq': 0.10758643756603131,
#   'r2': 0.9519645902305385,
#   'sensors': ['J163', 'P536', 'J67']},
#  {'node': 'J193',
#   'linreg': LinearRegression(),
#   'msq': 0.001472801604997264,
#   'r2': 0.9993130829600435,
#   'sensors': ['J67', 'P459', 'P536']},
#  {'node': 'J194',
#   'linreg': LinearRegression(),
#   'msq': 0.0004745917343606279,
#   'r2': 0.9997485539793385,
#   'sensors': ['J151', 'P213', 'J67']},
#  {'node': 'J195',
#   'linreg': LinearRegression(),
#   'msq': 0.008828452697630695,
#   'r2': 0.9958881574815306,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J196',
#   'linreg': LinearRegression(),
#   'msq': 0.0010926221192865196,
#   'r2': 0.9995902125929177,
#   'sensors': ['J151', 'P213', 'J113']},
#  {'node': 'J197',
#   'linreg': LinearRegression(),
#   'msq': 0.00012704452800859386,
#   'r2': 0.9999461212349353,
#   'sensors': ['P520', 'J60', 'J316']},
#  {'node': 'J198',
#   'linreg': LinearRegression(),
#   'msq': 0.0018063947779459063,
#   'r2': 0.9992514736972985,
#   'sensors': ['P520', 'J60', 'J316']},
#  {'node': 'J199',
#   'linreg': LinearRegression(),
#   'msq': 8.722586347139571e-05,
#   'r2': 0.999972420433668,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J200',
#   'linreg': LinearRegression(),
#   'msq': 2.7465239889924205e-05,
#   'r2': 0.9999887251798776,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J202',
#   'linreg': LinearRegression(),
#   'msq': 0.0002511741596746751,
#   'r2': 0.9999069914343518,
#   'sensors': ['P520', 'J316', 'J60']},
#  {'node': 'J203',
#   'linreg': LinearRegression(),
#   'msq': 4.057260481991854e-09,
#   'r2': 0.9999999981719188,
#   'sensors': ['J54', 'P46', 'J62']},
#  {'node': 'J204',
#   'linreg': LinearRegression(),
#   'msq': 8.321806765492906e-09,
#   'r2': 0.9999999945534861,
#   'sensors': ['J54', 'P46', 'J62']},
#  {'node': 'J205',
#   'linreg': LinearRegression(),
#   'msq': 3.473871703450945e-09,
#   'r2': 0.9999999982000339,
#   'sensors': ['P244', 'J129', 'J207']},
#  {'node': 'J206',
#   'linreg': LinearRegression(),
#   'msq': 5.189236846384284e-08,
#   'r2': 0.9999999788433623,
#   'sensors': ['P244', 'J129', 'J207']},
#  {'node': 'J207',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J207', 'J62', 'P55']},
#  {'node': 'J208',
#   'linreg': LinearRegression(),
#   'msq': 4.4025205443798806e-07,
#   'r2': 0.99999980441786,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J209',
#   'linreg': LinearRegression(),
#   'msq': 2.7029900095278145e-05,
#   'r2': 0.9999885648241367,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J210',
#   'linreg': LinearRegression(),
#   'msq': 0.004841150926946122,
#   'r2': 0.9979098103029428,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J211',
#   'linreg': LinearRegression(),
#   'msq': 6.335715471806339e-05,
#   'r2': 0.9999713588550363,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J212',
#   'linreg': LinearRegression(),
#   'msq': 0.0005960824174549384,
#   'r2': 0.9997746031953848,
#   'sensors': ['J33', 'P27', 'J151']},
#  {'node': 'J213',
#   'linreg': LinearRegression(),
#   'msq': 2.3100866382410244e-05,
#   'r2': 0.9999891477806669,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J214',
#   'linreg': LinearRegression(),
#   'msq': 0.020592192783040395,
#   'r2': 0.9913849489440388,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J216',
#   'linreg': LinearRegression(),
#   'msq': 0.0005622003664559073,
#   'r2': 0.9996657675534891,
#   'sensors': ['P536', 'J67', 'P459']},
#  {'node': 'J218',
#   'linreg': LinearRegression(),
#   'msq': 0.0005628769287314014,
#   'r2': 0.9997185452220778,
#   'sensors': ['P536', 'J163', 'J17']},
#  {'node': 'J219',
#   'linreg': LinearRegression(),
#   'msq': 0.39303460696077974,
#   'r2': 0.8703839927858528,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J220',
#   'linreg': LinearRegression(),
#   'msq': 7.214878434841415e-06,
#   'r2': 0.9999965603539998,
#   'sensors': ['J33', 'J137', 'P43']},
#  {'node': 'J223',
#   'linreg': LinearRegression(),
#   'msq': 0.007433477468291703,
#   'r2': 0.9966960164920549,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J224',
#   'linreg': LinearRegression(),
#   'msq': 0.00046607351107260184,
#   'r2': 0.9997828979067922,
#   'sensors': ['J163', 'P536', 'J172']},
#  {'node': 'J225',
#   'linreg': LinearRegression(),
#   'msq': 1.0780424081708886,
#   'r2': 0.7691903903750713,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J226',
#   'linreg': LinearRegression(),
#   'msq': 0.0014417211529271154,
#   'r2': 0.9993803805964531,
#   'sensors': ['J43', 'P174', 'P511']},
#  {'node': 'J227',
#   'linreg': LinearRegression(),
#   'msq': 0.004942665850217382,
#   'r2': 0.9977549026265989,
#   'sensors': ['J172', 'P174', 'J39']},
#  {'node': 'J228',
#   'linreg': LinearRegression(),
#   'msq': 0.0014971720855011135,
#   'r2': 0.9993218970471414,
#   'sensors': ['J113', 'P110', 'J151']},
#  {'node': 'J229',
#   'linreg': LinearRegression(),
#   'msq': 0.24467790275339513,
#   'r2': 0.9054179303699389,
#   'sensors': ['J172', 'P174', 'J67']},
#  {'node': 'J230',
#   'linreg': LinearRegression(),
#   'msq': 8.045357810409903e-08,
#   'r2': 0.9999999629587504,
#   'sensors': ['P56', 'J54', 'J64']},
#  {'node': 'J231',
#   'linreg': LinearRegression(),
#   'msq': 1.2806630704856338e-14,
#   'r2': 0.9999999999999936,
#   'sensors': ['J64', 'P56', 'J129']},
#  {'node': 'J232',
#   'linreg': LinearRegression(),
#   'msq': 0.000980818808977671,
#   'r2': 0.9994938452093411,
#   'sensors': ['P56', 'J64', 'J62']},
#  {'node': 'J233',
#   'linreg': LinearRegression(),
#   'msq': 7.535423311737599e-08,
#   'r2': 0.9999999707390954,
#   'sensors': ['J137', 'P43', 'J33']},
#  {'node': 'J235',
#   'linreg': LinearRegression(),
#   'msq': 2.306961155055793e-08,
#   'r2': 0.9999999898448159,
#   'sensors': ['J137', 'P43', 'J52']},
#  {'node': 'J236',
#   'linreg': LinearRegression(),
#   'msq': 5.884677797814177e-08,
#   'r2': 0.9999999777112225,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J239',
#   'linreg': LinearRegression(),
#   'msq': 6.916001989582635e-06,
#   'r2': 0.9999976964120979,
#   'sensors': ['J316', 'J146', 'P280']},
#  {'node': 'J240',
#   'linreg': LinearRegression(),
#   'msq': 0.005442614465622082,
#   'r2': 0.9978449983696953,
#   'sensors': ['P520', 'J316', 'J146']},
#  {'node': 'J241',
#   'linreg': LinearRegression(),
#   'msq': 6.974354965979175e-07,
#   'r2': 0.9999997822495357,
#   'sensors': ['J146', 'P280', 'J33']},
#  {'node': 'J242',
#   'linreg': LinearRegression(),
#   'msq': 1.0521437677197579e-06,
#   'r2': 0.9999995975926069,
#   'sensors': ['J146', 'P280', 'J33']},
#  {'node': 'J243',
#   'linreg': LinearRegression(),
#   'msq': 5.006432081234945e-08,
#   'r2': 0.9999999782984543,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J244',
#   'linreg': LinearRegression(),
#   'msq': 9.6021347653231e-29,
#   'r2': 1.0,
#   'sensors': ['J244', 'P266', 'P22']},
#  {'node': 'J245',
#   'linreg': LinearRegression(),
#   'msq': 0.013305083970289048,
#   'r2': 0.9999856278933872,
#   'sensors': ['P544', 'J244', 'P266']},
#  {'node': 'J246',
#   'linreg': LinearRegression(),
#   'msq': 1.354843640764391e-28,
#   'r2': 1.0,
#   'sensors': ['J244', 'P266', 'P22']},
#  {'node': 'J247',
#   'linreg': LinearRegression(),
#   'msq': 0.0006324032658338907,
#   'r2': 0.9997752346889472,
#   'sensors': ['J113', 'P110', 'J146']},
#  {'node': 'J248',
#   'linreg': LinearRegression(),
#   'msq': 0.0001266228785666625,
#   'r2': 0.999952799204551,
#   'sensors': ['P520', 'J39', 'P478']},
#  {'node': 'J249',
#   'linreg': LinearRegression(),
#   'msq': 2.608012621954379e-05,
#   'r2': 0.9999843447452066,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J250',
#   'linreg': LinearRegression(),
#   'msq': 1.6042682327569933e-05,
#   'r2': 0.999992681877482,
#   'sensors': ['P13', 'J17', 'J67']},
#  {'node': 'J251',
#   'linreg': LinearRegression(),
#   'msq': 2.139151332013642e-05,
#   'r2': 0.9999886260716152,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J252',
#   'linreg': LinearRegression(),
#   'msq': 0.0002169644614793642,
#   'r2': 0.9998852076275105,
#   'sensors': ['J67', 'P459', 'P13']},
#  {'node': 'J253',
#   'linreg': LinearRegression(),
#   'msq': 4.0710514544838576e-05,
#   'r2': 0.9999799235928402,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J254',
#   'linreg': LinearRegression(),
#   'msq': 2.4014635972564627e-05,
#   'r2': 0.9999897323374105,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J256',
#   'linreg': LinearRegression(),
#   'msq': 1.3703049532132415e-06,
#   'r2': 0.9999995025293622,
#   'sensors': ['P27', 'J33', 'J28']},
#  {'node': 'J257',
#   'linreg': LinearRegression(),
#   'msq': 3.057790454316844e-11,
#   'r2': 0.9999999999768736,
#   'sensors': ['J54', 'P56', 'P46']},
#  {'node': 'J258',
#   'linreg': LinearRegression(),
#   'msq': 3.567696647759022e-12,
#   'r2': 0.9999999999981268,
#   'sensors': ['J54', 'P46', 'J62']},
#  {'node': 'J259',
#   'linreg': LinearRegression(),
#   'msq': 0.001737804569586838,
#   'r2': 0.9992252768982857,
#   'sensors': ['P539', 'J539', 'P460']},
#  {'node': 'J260',
#   'linreg': LinearRegression(),
#   'msq': 0.0020766921859079693,
#   'r2': 0.999173223781608,
#   'sensors': ['P539', 'J539', 'J137']},
#  {'node': 'J261',
#   'linreg': LinearRegression(),
#   'msq': 4.877322022330363e-05,
#   'r2': 0.999994956688614,
#   'sensors': ['P539', 'J539', 'J137']},
#  {'node': 'J262',
#   'linreg': LinearRegression(),
#   'msq': 0.0022284259578712203,
#   'r2': 0.9989324368849812,
#   'sensors': ['P539', 'J539', 'J137']},
#  {'node': 'J263',
#   'linreg': LinearRegression(),
#   'msq': 0.04151594406227607,
#   'r2': 0.9999518821801977,
#   'sensors': ['P544', 'J244', 'P266']},
#  {'node': 'J264',
#   'linreg': LinearRegression(),
#   'msq': 0.015828136498021766,
#   'r2': 0.9999825421993567,
#   'sensors': ['P544', 'J244', 'P266']},
#  {'node': 'J265',
#   'linreg': LinearRegression(),
#   'msq': 0.013196502456835494,
#   'r2': 0.9999858987146477,
#   'sensors': ['P544', 'J244', 'P266']},
#  {'node': 'J267',
#   'linreg': LinearRegression(),
#   'msq': 8.89507737529789e-05,
#   'r2': 0.9999493458473329,
#   'sensors': ['P460', 'J284', 'P539']},
#  {'node': 'J269',
#   'linreg': LinearRegression(),
#   'msq': 4.38600051306001e-08,
#   'r2': 0.9999999735105968,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J273',
#   'linreg': LinearRegression(),
#   'msq': 5.879059780504579e-07,
#   'r2': 0.9999997602850533,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J274',
#   'linreg': LinearRegression(),
#   'msq': 0.0001911090423841159,
#   'r2': 0.9999266164357943,
#   'sensors': ['P520', 'J316', 'J60']},
#  {'node': 'J275',
#   'linreg': LinearRegression(),
#   'msq': 0.00020738825160168933,
#   'r2': 0.999920008695059,
#   'sensors': ['P520', 'J316', 'J60']},
#  {'node': 'J276',
#   'linreg': LinearRegression(),
#   'msq': 8.686865361382852e-06,
#   'r2': 0.9999967403645169,
#   'sensors': ['J316', 'J146', 'P280']},
#  {'node': 'J277',
#   'linreg': LinearRegression(),
#   'msq': 2.023576323804381e-05,
#   'r2': 0.9999920199339306,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J278',
#   'linreg': LinearRegression(),
#   'msq': 0.003329075837260173,
#   'r2': 0.9988842932592445,
#   'sensors': ['J151', 'P213', 'J33']},
#  {'node': 'J279',
#   'linreg': LinearRegression(),
#   'msq': 3.6538459739937424e-10,
#   'r2': 0.9999999997828037,
#   'sensors': ['P52', 'J60', 'J54']},
#  {'node': 'J280',
#   'linreg': LinearRegression(),
#   'msq': 2.0256013222868118e-06,
#   'r2': 0.9999991835262719,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J281',
#   'linreg': LinearRegression(),
#   'msq': 2.9056377860552365e-06,
#   'r2': 0.9999984771658815,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J282',
#   'linreg': LinearRegression(),
#   'msq': 5.7961784003576465e-05,
#   'r2': 0.9999708936806921,
#   'sensors': ['J67', 'P459', 'J52']},
#  {'node': 'J283',
#   'linreg': LinearRegression(),
#   'msq': 5.309978943734572e-05,
#   'r2': 0.9999777085939653,
#   'sensors': ['J67', 'P459', 'J52']},
#  {'node': 'J284',
#   'linreg': LinearRegression(),
#   'msq': 1.262177448353619e-29,
#   'r2': 1.0,
#   'sensors': ['J284', 'P460', 'P539']},
#  {'node': 'J285',
#   'linreg': LinearRegression(),
#   'msq': 1.5629513452694785e-10,
#   'r2': 0.9999999999330126,
#   'sensors': ['J284', 'P460', 'P539']},
#  {'node': 'J286',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J284', 'P460', 'P539']},
#  {'node': 'J287',
#   'linreg': LinearRegression(),
#   'msq': 0.027963667757043092,
#   'r2': 0.990972307297612,
#   'sensors': ['J316', 'P22', 'P520']},
#  {'node': 'J288',
#   'linreg': LinearRegression(),
#   'msq': 2.7068458063885802e-05,
#   'r2': 0.999991757674896,
#   'sensors': ['J316', 'P22', 'P520']},
#  {'node': 'J289',
#   'linreg': LinearRegression(),
#   'msq': 0.2414983312292027,
#   'r2': 0.9279999452865866,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J290',
#   'linreg': LinearRegression(),
#   'msq': 0.0001523214208764417,
#   'r2': 0.9999361672149325,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J291',
#   'linreg': LinearRegression(),
#   'msq': 0.0001492344840589687,
#   'r2': 0.9999417519497584,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J292',
#   'linreg': LinearRegression(),
#   'msq': 0.00010018646002718767,
#   'r2': 0.9999474957649701,
#   'sensors': ['J172', 'P174', 'J43']},
#  {'node': 'J293',
#   'linreg': LinearRegression(),
#   'msq': 6.09946389035007e-06,
#   'r2': 0.9999971066415507,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J294',
#   'linreg': LinearRegression(),
#   'msq': 5.492590061363636e-06,
#   'r2': 0.9999976692736156,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J295',
#   'linreg': LinearRegression(),
#   'msq': 9.71189216657201e-06,
#   'r2': 0.9999970873401406,
#   'sensors': ['J39', 'P478', 'P174']},
#  {'node': 'J296',
#   'linreg': LinearRegression(),
#   'msq': 4.152322426113252e-06,
#   'r2': 0.9999982616293513,
#   'sensors': ['P174', 'J172', 'J39']},
#  {'node': 'J297',
#   'linreg': LinearRegression(),
#   'msq': 3.121659238068613e-06,
#   'r2': 0.9999987343779857,
#   'sensors': ['P174', 'J172', 'J39']},
#  {'node': 'J298',
#   'linreg': LinearRegression(),
#   'msq': 1.6336017517682262e-05,
#   'r2': 0.9999945552831017,
#   'sensors': ['P520', 'J316', 'J39']},
#  {'node': 'J299',
#   'linreg': LinearRegression(),
#   'msq': 0.00028061214713008965,
#   'r2': 0.9998832978480167,
#   'sensors': ['P520', 'J39', 'P478']},
#  {'node': 'J300',
#   'linreg': LinearRegression(),
#   'msq': 0.0003412332416223126,
#   'r2': 0.9998481268328747,
#   'sensors': ['J284', 'P9', 'P460']},
#  {'node': 'J301',
#   'linreg': LinearRegression(),
#   'msq': 0.0003815344567717908,
#   'r2': 0.9997907621948937,
#   'sensors': ['J284', 'P9', 'P460']},
#  {'node': 'J302',
#   'linreg': LinearRegression(),
#   'msq': 0.0004698792648810825,
#   'r2': 0.9997477661902137,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J303',
#   'linreg': LinearRegression(),
#   'msq': 0.0008163928659866165,
#   'r2': 0.9996064870830957,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J304',
#   'linreg': LinearRegression(),
#   'msq': 0.0013009699825104475,
#   'r2': 0.9993346432284048,
#   'sensors': ['J163', 'P536', 'J43']},
#  {'node': 'J305',
#   'linreg': LinearRegression(),
#   'msq': 4.043594893260729e-06,
#   'r2': 0.9999974044697066,
#   'sensors': ['P13', 'J17', 'J12']},
#  {'node': 'J306',
#   'linreg': LinearRegression(),
#   'msq': 1.0862424626674731e-05,
#   'r2': 0.9999941419918389,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J307',
#   'linreg': LinearRegression(),
#   'msq': 1.5802402903412713e-07,
#   'r2': 0.9999999014100589,
#   'sensors': ['J79', 'P500', 'J12']},
#  {'node': 'J308',
#   'linreg': LinearRegression(),
#   'msq': 7.20758123314891e-06,
#   'r2': 0.9999967025085064,
#   'sensors': ['J79', 'P500', 'J67']},
#  {'node': 'J309',
#   'linreg': LinearRegression(),
#   'msq': 6.682200864289395e-08,
#   'r2': 0.999999969542588,
#   'sensors': ['J67', 'P459', 'J79']},
#  {'node': 'J310',
#   'linreg': LinearRegression(),
#   'msq': 1.1212546993924613e-06,
#   'r2': 0.9999994083080762,
#   'sensors': ['J67', 'P459', 'J79']},
#  {'node': 'J311',
#   'linreg': LinearRegression(),
#   'msq': 3.845273636033316e-05,
#   'r2': 0.9999853810519428,
#   'sensors': ['J172', 'P174', 'J67']},
#  {'node': 'J312',
#   'linreg': LinearRegression(),
#   'msq': 3.3681818104890295e-06,
#   'r2': 0.9999986551593889,
#   'sensors': ['J43', 'P511', 'P46']},
#  {'node': 'J313',
#   'linreg': LinearRegression(),
#   'msq': 1.0119804076813552e-05,
#   'r2': 0.9999957020662392,
#   'sensors': ['J43', 'P511', 'J163']},
#  {'node': 'J314',
#   'linreg': LinearRegression(),
#   'msq': 1.709377446375991e-05,
#   'r2': 0.999991037861208,
#   'sensors': ['J113', 'P110', 'J39']},
#  {'node': 'J315',
#   'linreg': LinearRegression(),
#   'msq': 4.1945876935802504e-05,
#   'r2': 0.9999814169879125,
#   'sensors': ['J113', 'P110', 'J39']},
#  {'node': 'J316',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J316', 'P520', 'P22']},
#  {'node': 'J317',
#   'linreg': LinearRegression(),
#   'msq': 3.603457345474872e-06,
#   'r2': 0.9999985843435296,
#   'sensors': ['J316', 'P520', 'P22']},
#  {'node': 'J318',
#   'linreg': LinearRegression(),
#   'msq': 0.0003852508437197719,
#   'r2': 0.9998208185628795,
#   'sensors': ['J79', 'P500', 'P9']},
#  {'node': 'J319',
#   'linreg': LinearRegression(),
#   'msq': 3.124605161938362e-06,
#   'r2': 0.9999989775288554,
#   'sensors': ['J316', 'P520', 'P22']},
#  {'node': 'J320',
#   'linreg': LinearRegression(),
#   'msq': 1.8937223726027567e-07,
#   'r2': 0.9999999379538008,
#   'sensors': ['J316', 'P520', 'P22']},
#  {'node': 'J321',
#   'linreg': LinearRegression(),
#   'msq': 0.33423790469084563,
#   'r2': 0.9852682630998942,
#   'sensors': ['P22', 'J316', 'J28']},
#  {'node': 'J322',
#   'linreg': LinearRegression(),
#   'msq': 1.794568154239284e-09,
#   'r2': 0.999999999094777,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J323',
#   'linreg': LinearRegression(),
#   'msq': 0.00011271672461465454,
#   'r2': 0.9999573619156374,
#   'sensors': ['P520', 'J39', 'P478']},
#  {'node': 'J324',
#   'linreg': LinearRegression(),
#   'msq': 5.156740820181028e-05,
#   'r2': 0.9999741134589979,
#   'sensors': ['J67', 'P459', 'J52']},
#  {'node': 'J326',
#   'linreg': LinearRegression(),
#   'msq': 2.0077959826727576e-05,
#   'r2': 0.9999901342433322,
#   'sensors': ['J12', 'P13', 'J79']},
#  {'node': 'J327',
#   'linreg': LinearRegression(),
#   'msq': 2.5013486680919158e-14,
#   'r2': 0.9999999999999889,
#   'sensors': ['J52', 'P45', 'J137']},
#  {'node': 'J539',
#   'linreg': LinearRegression(),
#   'msq': 0.0,
#   'r2': 1.0,
#   'sensors': ['J539', 'P539', 'J137']},
#  {'node': 'J544',
#   'linreg': LinearRegression(),
#   'msq': 0.013403462278741582,
#   'r2': 0.9999845713667007,
#   'sensors': ['P544', 'J244', 'P266']},
#  {'node': 'J546',
#   'linreg': LinearRegression(),
#   'msq': 0.03500491732055697,
#   'r2': 0.9999638438725439,
#   'sensors': ['P544', 'J244', 'P266']},
#  {'node': 'T1',
#   'linreg': LinearRegression(),
#   'msq': 0.1277801020426148,
#   'r2': 0.9160019175985321,
#   'sensors': ['P460', 'J284', 'P539']},
#  {'node': 'T2',
#   'linreg': LinearRegression(),
#   'msq': 0.003172214927225728,
#   'r2': 0.9981125395936037,
#   'sensors': ['J54', 'P52', 'P46']}]

# %%
# simulate a leak scenario
sim_LEAK = wntr_WSN.get_sim_results_LEAK(leak_node, leak_area, leak_start, leak_end)

# join pressures and flowrates
sim_LEAK_raw = pd.concat([sim_LEAK.node['pressure'], sim_LEAK.link['flowrate']], axis=1)
predictions = {}

# for each node in graph
G = ng.create_graph()
for node in G.nodes():

    # find linear regression model for this particular node
    for model in linreg_models:
        if model['node'] == node:
            linreg_dict = model

    # choose only the available sensors
    sim_LEAK_scope = sim_LEAK_raw[linreg_dict['sensors']]

    # normalise the input data with respective parameters
    sim_LEAK_scope = (sim_LEAK_scope - normalization_params['mean'].loc[linreg_dict['sensors']]) / normalization_params['std'].loc[linreg_dict['sensors']]

    # predict pressure for each node
    predictions[node] = linreg_dict['linreg'].predict(sim_LEAK_scope)

# "sim_duration*6" because (60 minutes = 10 minutes * 6)
# it's related to simulation step time 
index = [600*i for i in range(0, (sim_duration*6)+1)]

pred_LEAK_results = pd.DataFrame(data=predictions, index=index)
pred_LEAK_results
# Out:
# c:\users\pc\anaconda3\envs\wodociagi\lib\site-packages\scipy\optimize\minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# Creating a NetworkX graph from .inp file (networkx_graph.py - create_graph())
#                J1         J2         J3         J4         J5         J6  \
# 0       36.007728  30.043946  29.924401  31.958709  32.148558  45.656096
# 600     38.995160  33.155931  33.036006  35.025148  35.215815  48.320933
# 1200    39.116052  33.277189  33.157258  35.146255  35.336938  48.442713
# 1800    36.748178  30.906448  30.786441  32.776993  32.967176  46.008250
# 2400    36.714150  30.872316  30.752312  32.742904  32.933083  45.973971
# ...           ...        ...        ...        ...        ...        ...
# 465600  32.274378  26.460614  26.340631  28.321744  28.511380  41.543831
# 466200  32.185867  26.373761  26.253760  28.234313  28.423923  41.455189
# 466800  32.100813  26.288083  26.168086  28.148874  28.338471  41.369494
# 467400  32.016400  26.203089  26.083097  28.064103  28.253688  41.284434
# 468000  31.932555  26.118703  25.998716  27.979926  28.169498  41.199940
#
#                J7         J8         J9        J10  ...       J322       J323  \
# 0       31.842500  28.841451  33.860558  43.419479  ...  39.770512  70.297167
# 600     34.824782  31.824736  36.845347  46.002609  ...  42.109475  72.072027
# 1200    34.945636  31.945608  36.966216  46.124199  ...  42.230851  72.193733
# 1800    32.578082  29.578119  34.598261  43.710317  ...  39.060846  68.986034
# 2400    32.544065  29.544096  34.564239  43.676092  ...  39.026682  68.951776
# ...           ...        ...        ...        ...  ...        ...        ...
# 465600  28.104025  25.103830  30.124328  39.232900  ...  34.504603  64.433670
# 466200  28.015443  25.015286  30.035751  39.144698  ...  34.419044  64.348648
# 466800  27.930430  24.930259  29.950720  39.059392  ...  34.334990  64.265235
# 467400  27.846055  24.845870  29.866329  38.974692  ...  34.251417  64.182202
# 468000  27.762246  24.762049  29.782505  38.890530  ...  34.168272  64.099508
#
#              J324       J326       J327       J539       J544       J546  \
# 0       43.725289  49.239213  27.804030  30.955127  83.333916  79.320369
# 600     45.880900  51.501378  30.138199  30.583525  85.060845  81.056026
# 1200    46.002615  51.622721  30.259576  30.704902  85.172661  81.168453
# 1800    43.241612  49.267862  27.100760  27.511339  24.344780  21.084591
# 2400    43.207352  49.233707  27.066595  27.477174  24.313286  21.052974
# ...           ...        ...        ...        ...        ...        ...
# 465600  38.671457  44.749682  22.543039  23.069615  20.160332  16.878780
# 466200  38.584743  44.663115  22.457443  22.984958  20.082207  16.800167
# 466800  38.500540  44.579043  22.373392  22.899159  20.005425  16.723079
# 467400  38.416806  44.495449  22.289821  22.814050  19.929131  16.646297
# 468000  38.333491  44.412284  22.206678  22.729553  19.853081  16.569881
#
#                T1         T2
# 0       25.459113  19.839908
# 600     28.321491  20.400044
# 1200    28.419035  20.520383
# 1800    26.512908  20.167304
# 2400    26.485451  20.133432
# ...           ...        ...
# 465600  23.059765  16.318970
# 466200  22.994623  16.240604
# 466800  22.924540  16.162398
# 467400  22.855141  16.084085
# 468000  22.786349  16.005680
#
# [781 rows x 309 columns]

# %% [markdown]
# ## Get results of leak scenario

# %%
sim_LEAK_results = pd.concat([sim_LEAK.node['pressure'], sim_LEAK.link['flowrate']], axis=1)
sim_LEAK_results
# Out:
#                J1         J2         J3         J4         J5         J6  \
# 0       36.011416  30.044852  29.924852  31.958688  32.148688  45.531102
# 600     38.996412  33.156409  33.036409  35.026409  35.216409  48.256448
# 1200    39.117789  33.277785  33.157785  35.147786  35.337786  48.377824
# 1800    36.745965  30.905961  30.785961  32.775962  32.965962  46.006000
# 2400    36.711800  30.871797  30.751797  32.741797  32.931797  45.971836
# ...           ...        ...        ...        ...        ...        ...
# 465600  32.287546  26.463700  26.343700  28.328067  28.518067  41.516770
# 466200  32.199657  26.376986  26.256986  28.240945  28.430945  41.429355
# 466800  32.114172  26.291202  26.171202  28.155264  28.345264  41.344436
# 467400  32.029338  26.206106  26.086106  28.070259  28.260259  41.260099
# 468000  31.945081  26.121619  26.001619  27.985852  28.175852  41.176279
#
#                J7         J8         J9        J10  ...      P548      P549  \
# 0       31.841401  28.841400  33.861399  43.310270  ...  0.005835 -0.001642
# 600     34.826398  31.826397  36.846395  45.955310  ... -0.003068  0.000596
# 1200    34.947774  31.947773  36.967772  46.076686  ... -0.003068  0.000596
# 1800    32.575951  29.575950  34.595948  43.706562  ...  0.001599 -0.000348
# 2400    32.541786  29.541785  34.561783  43.672397  ...  0.001599 -0.000348
# ...           ...        ...        ...        ...  ...       ...       ...
# 465600  28.117472  25.117466  30.137446  39.212196  ...  0.002238 -0.000472
# 466200  28.029243  25.029191  30.049191  39.124934  ...  0.002277 -0.000481
# 466800  27.943758  24.943705  29.963705  39.040154  ...  0.002303 -0.000487
# 467400  27.858923  24.858871  29.878871  38.955939  ...  0.002325 -0.000493
# 468000  27.774667  24.774614  29.794615  38.872225  ...  0.002345 -0.000497
#
#             P551      P553     PMP51  PMP63   PMP72     FCV51  FCV63   FCV72
# 0       0.001183 -0.000037  0.020833    0.0  0.0434  0.020833    0.0  0.0434
# 600    -0.000168 -0.000035  0.000000    0.0  0.0434  0.000000    0.0  0.0434
# 1200   -0.000168 -0.000035  0.000000    0.0  0.0434  0.000000    0.0  0.0434
# 1800    0.000072 -0.000008  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# 2400    0.000072 -0.000008  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# ...          ...       ...       ...    ...     ...       ...    ...     ...
# 465600 -0.000261 -0.000033  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# 466200 -0.000258 -0.000033  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# 466800 -0.000255 -0.000033  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# 467400 -0.000252 -0.000033  0.000000    0.0  0.0000  0.000000    0.0  0.0000
# 468000 -0.000250 -0.000033  0.000000    0.0  0.0000  0.000000    0.0  0.0000
#
# [781 rows x 679 columns]

# %% [markdown]
# ## Calculate residuum

# %%
residuals = sim_LEAK.node['pressure'] - pred_LEAK_results
residuals
# Out:
#               J1       J10      J100      J102      J103      J104      J105  \
# 0       0.003687 -0.109209  0.011408  0.027907  0.013708  0.012505 -0.005332
# 600     0.001252 -0.047299 -0.039084 -0.027194 -0.009116  0.003952 -0.004576
# 1200    0.001736 -0.047513 -0.038637 -0.026882 -0.009232  0.003735 -0.004569
# 1800   -0.002213 -0.003755 -0.003068 -0.002196  0.000417  0.002022  0.003481
# 2400   -0.002349 -0.003694 -0.003194 -0.002284  0.000450  0.002083  0.003479
# ...          ...       ...       ...       ...       ...       ...       ...
# 465600  0.013168 -0.020704 -0.009884 -0.011965 -0.008830 -0.002837 -0.001542
# 466200  0.013791 -0.019764 -0.009016 -0.011202 -0.008611 -0.002678 -0.001509
# 466800  0.013359 -0.019238 -0.009300 -0.011429 -0.008618 -0.002499 -0.001507
# 467400  0.012937 -0.018753 -0.009584 -0.011652 -0.008616 -0.002324 -0.001506
# 468000  0.012526 -0.018305 -0.009867 -0.011870 -0.008605 -0.002154 -0.001505
#
#             J106      J107      J108  ...       J98       J99  JPMP51  JPMP63  \
# 0      -0.006691 -0.017601  0.035667  ...  0.008589  0.027087     NaN     NaN
# 600    -0.005254 -0.007135  0.002183  ... -0.040772 -0.033877     NaN     NaN
# 1200   -0.005303 -0.007103  0.002171  ... -0.040328 -0.033429     NaN     NaN
# 1800    0.002464  0.003436  0.001874  ... -0.003166 -0.001375     NaN     NaN
# 2400    0.002477  0.003427  0.001877  ... -0.003291 -0.001501     NaN     NaN
# ...          ...       ...       ...  ...       ...       ...     ...     ...
# 465600 -0.000557 -0.001875 -0.004576  ... -0.009853 -0.009901     NaN     NaN
# 466200 -0.000502 -0.001896 -0.004208  ... -0.008908 -0.009230     NaN     NaN
# 466800 -0.000471 -0.001955 -0.004175  ... -0.009180 -0.009518     NaN     NaN
# 467400 -0.000441 -0.002010 -0.004145  ... -0.009452 -0.009806     NaN     NaN
# 468000 -0.000411 -0.002062 -0.004117  ... -0.009726 -0.010093     NaN     NaN
#
#         JPMP72  R5  R6  R7        T1        T2
# 0          NaN NaN NaN NaN  0.540887  0.160092
# 600        NaN NaN NaN NaN -2.101202 -0.315379
# 1200       NaN NaN NaN NaN -2.198747 -0.314342
# 1800       NaN NaN NaN NaN -0.292619  0.009757
# 2400       NaN NaN NaN NaN -0.265163  0.009464
# ...        ...  ..  ..  ..       ...       ...
# 465600     NaN NaN NaN NaN -0.363185 -0.027191
# 466200     NaN NaN NaN NaN -0.382425 -0.025979
# 466800     NaN NaN NaN NaN -0.398718 -0.025284
# 467400     NaN NaN NaN NaN -0.414936 -0.024740
# 468000     NaN NaN NaN NaN -0.431089 -0.024331
#
# [781 rows x 315 columns]

# %% [markdown]
# ## Take care of column naming convention

# %%
residuals = residuals.add_suffix('_residuum')

sim_LEAK.node['pressure'] = sim_LEAK.node['pressure'].add_suffix('_pressure')
sim_LEAK.link['flowrate'] = sim_LEAK.link['flowrate'].add_suffix('_flow')
sim_LEAK = pd.concat([sim_LEAK.node['pressure'], sim_LEAK.link['flowrate']], axis=1)

pred_LEAK_results = pred_LEAK_results.add_suffix('_model_output')

# %% [markdown]
# ## Sanity check

# %%
print(f'Number of residuals columns: {len(residuals.columns)}')
print(f'Number of sim_LEAK columns: {len(sim_LEAK.columns)}')
print(f'Number of pred_LEAK_results columns: {len(pred_LEAK_results.columns)}')
print(f'Sum: {len(residuals.columns) + len(sim_LEAK.columns) + len(pred_LEAK_results.columns)}')
# Out:
# Number of residuals columns: 315
# Number of sim_LEAK columns: 679
# Number of pred_LEAK_results columns: 309
# Sum: 1303

# %% [markdown]
# ## Form final dataframe

# %%
output = pd.concat([residuals, sim_LEAK, pred_LEAK_results], axis=1)
output
# Out:
#         J1_residuum  J10_residuum  J100_residuum  J102_residuum  \
# 0          0.003687     -0.109209       0.011408       0.027907
# 600        0.001252     -0.047299      -0.039084      -0.027194
# 1200       0.001736     -0.047513      -0.038637      -0.026882
# 1800      -0.002213     -0.003755      -0.003068      -0.002196
# 2400      -0.002349     -0.003694      -0.003194      -0.002284
# ...             ...           ...            ...            ...
# 465600     0.013168     -0.020704      -0.009884      -0.011965
# 466200     0.013791     -0.019764      -0.009016      -0.011202
# 466800     0.013359     -0.019238      -0.009300      -0.011429
# 467400     0.012937     -0.018753      -0.009584      -0.011652
# 468000     0.012526     -0.018305      -0.009867      -0.011870
#
#         J103_residuum  J104_residuum  J105_residuum  J106_residuum  \
# 0            0.013708       0.012505      -0.005332      -0.006691
# 600         -0.009116       0.003952      -0.004576      -0.005254
# 1200        -0.009232       0.003735      -0.004569      -0.005303
# 1800         0.000417       0.002022       0.003481       0.002464
# 2400         0.000450       0.002083       0.003479       0.002477
# ...               ...            ...            ...            ...
# 465600      -0.008830      -0.002837      -0.001542      -0.000557
# 466200      -0.008611      -0.002678      -0.001509      -0.000502
# 466800      -0.008618      -0.002499      -0.001507      -0.000471
# 467400      -0.008616      -0.002324      -0.001506      -0.000441
# 468000      -0.008605      -0.002154      -0.001505      -0.000411
#
#         J107_residuum  J108_residuum  ...  J322_model_output  \
# 0           -0.017601       0.035667  ...          39.770512
# 600         -0.007135       0.002183  ...          42.109475
# 1200        -0.007103       0.002171  ...          42.230851
# 1800         0.003436       0.001874  ...          39.060846
# 2400         0.003427       0.001877  ...          39.026682
# ...               ...            ...  ...                ...
# 465600      -0.001875      -0.004576  ...          34.504603
# 466200      -0.001896      -0.004208  ...          34.419044
# 466800      -0.001955      -0.004175  ...          34.334990
# 467400      -0.002010      -0.004145  ...          34.251417
# 468000      -0.002062      -0.004117  ...          34.168272
#
#         J323_model_output  J324_model_output  J326_model_output  \
# 0               70.297167          43.725289          49.239213
# 600             72.072027          45.880900          51.501378
# 1200            72.193733          46.002615          51.622721
# 1800            68.986034          43.241612          49.267862
# 2400            68.951776          43.207352          49.233707
# ...                   ...                ...                ...
# 465600          64.433670          38.671457          44.749682
# 466200          64.348648          38.584743          44.663115
# 466800          64.265235          38.500540          44.579043
# 467400          64.182202          38.416806          44.495449
# 468000          64.099508          38.333491          44.412284
#
#         J327_model_output  J539_model_output  J544_model_output  \
# 0               27.804030          30.955127          83.333916
# 600             30.138199          30.583525          85.060845
# 1200            30.259576          30.704902          85.172661
# 1800            27.100760          27.511339          24.344780
# 2400            27.066595          27.477174          24.313286
# ...                   ...                ...                ...
# 465600          22.543039          23.069615          20.160332
# 466200          22.457443          22.984958          20.082207
# 466800          22.373392          22.899159          20.005425
# 467400          22.289821          22.814050          19.929131
# 468000          22.206678          22.729553          19.853081
#
#         J546_model_output  T1_model_output  T2_model_output
# 0               79.320369        25.459113        19.839908
# 600             81.056026        28.321491        20.400044
# 1200            81.168453        28.419035        20.520383
# 1800            21.084591        26.512908        20.167304
# 2400            21.052974        26.485451        20.133432
# ...                   ...              ...              ...
# 465600          16.878780        23.059765        16.318970
# 466200          16.800167        22.994623        16.240604
# 466800          16.723079        22.924540        16.162398
# 467400          16.646297        22.855141        16.084085
# 468000          16.569881        22.786349        16.005680
#
# [781 rows x 1303 columns]

# %% [markdown]
# ## Export the final dataframe to .xlsx

# %%
if comment:
    output.to_excel(os.path.join(os.getcwd(), f'{method}_n{leak_node}_la{leak_area}_lst{leak_start}_let{leak_end}_{comment}.xlsx'))
else:
    output.to_excel(os.path.join(os.getcwd(), f'{method}_n{leak_node}_la{leak_area}_lst{leak_start}_let{leak_end}.xlsx'))
